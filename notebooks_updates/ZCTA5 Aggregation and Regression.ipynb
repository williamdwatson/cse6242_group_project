# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.linear_model import ElasticNet, ElasticNetCV, LassoCV, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler, RobustScaler, scale
import seaborn as sns

# %%
place_abbr = 'cinci'

tracts_deserts_path = 'data/tract_desert_measures/cinci_desert_tracts.csv'

save_data_dir = 'data/zcta_health/'
save_data_name =  place_abbr+'_zcta_health.csv'
save_transf_data_name =  place_abbr+'_zcta_health_logt.csv'

save_regression_path = 'data/zcta_health/results/'
save_lasso_name = place_abbr+'_zcta_lasso_results'
save_enet_name = place_abbr+'_zcta_enet_results'

# %% [markdown]
# # Aggregation/Cleaning

# %%
tracts_deserts = pd.read_csv(tracts_deserts_path, dtype={'GEOID':'str'})

# %%
zip_to_tract = pd.read_csv("data/zcta_to_tract10.csv", dtype=str)
zip_to_tract = zip_to_tract[['GEOID', 'ZCTA5']]

# %%
tracts_zcta_deserts = pd.merge(tracts_deserts, zip_to_tract, on='GEOID').groupby('ZCTA5', as_index=False).median()

# %%
zcta_health = pd.read_csv("data/PLACES__ZCTA_Data__GIS_Friendly_Format___2021_release.csv", dtype={'ZCTA5':'str', 'GEOID':'str'})
zcta_health = pd.merge(zcta_health, tracts_zcta_deserts, on='ZCTA5')

income_vars = pd.read_csv('data/ZCTA_median_incomes.csv', dtype=str).rename(columns={'ZCTA':'ZCTA5'})
zcta_health = pd.merge(zcta_health, income_vars, on='ZCTA5')

zcta_health.to_csv(save_data_dir+save_data_name, index=False)

# %%
zcta_health.loc[zcta_health['Household median income'] == '-', 'Household median income'] = 'nan'
zcta_health['Household median income'] = zcta_health['Household median income'].str.replace('+', '').str.replace(',','')
zcta_health = zcta_health.astype({'Household median income':'float'})
zcta_health['Household median income'] = zcta_health['Household median income'].fillna(zcta_health['Household median income'].median())
# Out:
# /var/folders/xv/tskjqjvs1hd9_5_96mmdcbnw0000gn/T/ipykernel_55241/1766290430.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   zcta_health['Household median income'] = zcta_health['Household median income'].str.replace('+', '').str.replace(',','')

# %%
desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']

zcta_health_logt = zcta_health.copy()
zcta_health_logt[desert_measures] = zcta_health_logt[desert_measures].apply(lambda x: np.log(x+1))
zcta_health_logt.to_csv(save_transf_data_name, index=False)

# %% [markdown]
# # Analysis

# %%
name_mapping = {'access2': 'Health insurance access', 'arthritis': 'Arthritis prevalence', 'binge': 'Binge drinking prevalence',
               'bphigh': 'High blood pressure prevalence', 'bpmed': 'Medium blood pressure prevalence', 'cancer': 'Cancer prevalence',
               'casthma': 'Asthma prevalence', 'cervical': 'Cervical cancer screenings', 'chd': 'Coronary heart disease prevalence',
               'checkup': 'Routine checkups', 'cholscreen': 'Cholesterol screenings', 'colon_screen': 'Colon cancer screenings',
               'copd': 'COPD prevalence', 'corem': 'Core men\'s health', 'corew': 'Core women\'s health', 'csmoking': 'Smoking prevalence',
               'dental': 'Dental checkups', 'depression': 'Depression prevalence', 'diabetes': 'Diabetes prevalence', 'ghlth': 'General poor health prevalence',
               'highchol': 'High cholesterol prevalence', 'kidney': 'Chronic kidney disease', 'lpa': 'No physical activity', 'mammouse': 'Mammograms',
               'mhlth': 'Poor mental health prevalence', 'obesity': 'Obesity prevalence', 'phlth': 'Poor physical health', 'sleep': 'Poor sleep prevalence',
               'stroke': 'Stroke prevalence', 'teethlost': 'Teeth loss prevalence'}

results_nan = pd.DataFrame({'Health condition': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'Food': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')],
                       'Physical health': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'Public transport': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')],
                        'Education': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'Houses of worship': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')],
                       'RSquared': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'MSE': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')]})

desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']

# %%
zcta_health
# Out:
#     ZCTA5 TotalPopulation  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 0   45244          28,565                8.9      ( 8.0,  9.8)
# 1   45232           6,358               21.0      (17.5, 25.0)
# 2   45206          10,745               14.3      (13.2, 15.5)
# 3   45239          28,315               12.4      (11.6, 13.1)
# 4   45214           8,738               18.8      (17.3, 20.4)
# 5   45229          13,020               18.2      (16.5, 19.8)
# 6   45238          45,760               12.0      (11.3, 12.6)
# 7   45224          19,837               12.4      (11.7, 13.3)
# 8   45225           9,040               21.5      (19.9, 23.5)
# 9   45207           7,974               14.6      (12.6, 17.0)
# 10  45213          12,013               10.0      ( 9.0, 11.0)
# 11  45231          40,893               12.1      (11.5, 12.7)
# 12  45237          20,021               15.0      (13.9, 16.2)
# 13  45219          16,526               14.5      (13.1, 15.9)
# 14  45203           2,236               16.0      (13.9, 18.3)
# 15  45217           6,566               12.4      (10.9, 13.8)
# 16  45212          22,253               12.3      (11.3, 13.4)
# 17  45230          27,536                8.3      ( 7.5,  9.1)
# 18  45220          15,313               12.0      (10.7, 14.2)
# 19  45216           9,570               17.2      (15.9, 18.5)
# 20  45208          17,614                6.0      ( 5.4,  6.7)
# 21  45226           5,476                7.9      ( 6.9,  9.0)
# 22  45204           6,972               19.7      (18.4, 21.1)
# 23  45202          15,483               11.3      (10.4, 12.2)
# 24  45248          24,915                8.6      ( 7.8,  9.4)
# 25  45211          36,111               13.7      (12.9, 14.5)
# 26  45233          15,808                8.6      ( 7.7,  9.5)
# 27  45209           9,605                7.9      ( 6.8,  9.2)
# 28  45215          29,623               12.4      (11.6, 13.2)
# 29  45227          17,486                9.7      ( 8.9, 10.6)
# 30  45205          19,389               17.9      (16.9, 18.9)
# 31  45223          12,360               14.1      (12.7, 15.4)
#
#     ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev BINGE_Crude95CI  \
# 0                  25.8        (25.2, 26.4)             19.9    (19.6, 20.2)
# 1                  25.4        (24.5, 26.2)             15.6    (15.0, 16.3)
# 2                  27.8        (27.3, 28.3)             17.4    (17.2, 17.7)
# 3                  27.4        (27.0, 27.8)             19.6    (19.3, 19.8)
# 4                  29.0        (28.5, 29.4)             15.8    (15.5, 16.1)
# 5                  33.1        (32.6, 33.7)             13.8    (13.5, 14.1)
# 6                  26.9        (26.5, 27.2)             20.3    (20.1, 20.5)
# 7                  32.3        (31.8, 32.7)             15.7    (15.5, 15.9)
# 8                  25.7        (25.3, 26.1)             16.3    (15.9, 16.7)
# 9                  22.2        (21.6, 22.8)             19.2    (18.3, 20.1)
# 10                 25.8        (25.2, 26.4)             18.9    (18.7, 19.2)
# 11                 29.4        (29.0, 29.7)             18.0    (17.9, 18.2)
# 12                 33.0        (32.4, 33.4)             14.5    (14.3, 14.7)
# 13                 14.9        (14.6, 15.2)             22.9    (22.1, 23.7)
# 14                 26.5        (25.7, 27.2)             16.2    (15.8, 16.7)
# 15                 28.5        (27.8, 29.3)             18.7    (18.2, 19.2)
# 16                 24.4        (24.0, 24.8)             21.5    (21.1, 21.9)
# 17                 26.0        (25.5, 26.6)             21.1    (20.9, 21.4)
# 18                 18.2        (17.8, 18.6)             21.8    (21.2, 22.5)
# 19                 30.6        (30.1, 31.2)             17.5    (17.2, 17.8)
# 20                 21.0        (20.6, 21.5)             23.2    (22.8, 23.6)
# 21                 19.7        (19.2, 20.3)             24.8    (24.2, 25.4)
# 22                 27.1        (26.7, 27.5)             19.1    (18.7, 19.5)
# 23                 21.2        (20.8, 21.5)             22.0    (21.7, 22.3)
# 24                 27.3        (26.7, 27.8)             21.0    (20.8, 21.3)
# 25                 27.3        (26.9, 27.6)             19.3    (19.1, 19.5)
# 26                 27.6        (26.9, 28.3)             20.8    (20.5, 21.2)
# 27                 19.0        (18.5, 19.5)             24.5    (23.9, 25.0)
# 28                 28.9        (28.5, 29.3)             18.4    (18.1, 18.6)
# 29                 25.1        (24.7, 25.6)             20.0    (19.7, 20.2)
# 30                 27.3        (26.9, 27.7)             18.4    (18.2, 18.7)
# 31                 25.8        (25.3, 26.2)             18.4    (18.1, 18.7)
#
#     BPHIGH_CrudePrev BPHIGH_Crude95CI  ...                       Geolocation  \
# 0               30.2     (29.6, 30.9)  ...  POINT (-84.32730222 39.11990357)
# 1               38.2     (36.9, 39.3)  ...  POINT (-84.51090978 39.18269919)
# 2               39.3     (38.8, 39.8)  ...  POINT (-84.48439299 39.12733748)
# 3               34.0     (33.6, 34.5)  ...  POINT (-84.57989885 39.20453166)
# 4               42.5     (42.0, 43.1)  ...  POINT (-84.53147941 39.11788621)
# 5               48.8     (48.1, 49.5)  ...  POINT (-84.48679989 39.15274569)
# 6               32.3     (31.9, 32.7)  ...  POINT (-84.61144742 39.10905551)
# 7               42.5     (41.9, 42.9)  ...    POINT (-84.547293 39.19892379)
# 8               39.5     (38.9, 40.0)  ...  POINT (-84.53872675 39.13580846)
# 9               34.2     (33.4, 34.9)  ...   POINT (-84.47133581 39.1420676)
# 10              35.3     (34.7, 35.9)  ...   POINT (-84.4200955 39.18080136)
# 11              37.3     (37.0, 37.7)  ...   POINT (-84.5319695 39.23666006)
# 12              46.8     (46.2, 47.3)  ...   POINT (-84.4509225 39.19660237)
# 13              23.3     (22.7, 23.8)  ...  POINT (-84.51306369 39.12737628)
# 14              40.1     (39.1, 41.0)  ...  POINT (-84.53347928 39.10432578)
# 15              37.0     (36.2, 37.8)  ...  POINT (-84.49732986 39.16756823)
# 16              29.9     (29.4, 30.3)  ...  POINT (-84.45218766 39.16419042)
# 17              29.8     (29.2, 30.4)  ...  POINT (-84.39097174 39.07435397)
# 18              25.1     (24.6, 25.6)  ...  POINT (-84.52072339 39.14863212)
# 19              39.0     (38.4, 39.6)  ...  POINT (-84.48175259 39.20091825)
# 20              24.5     (24.0, 24.9)  ...  POINT (-84.44887175 39.13460442)
# 21              23.3     (22.8, 24.0)  ...  POINT (-84.42042941 39.11078689)
# 22              34.8     (34.4, 35.3)  ...  POINT (-84.56408475 39.09190716)
# 23              31.7     (31.3, 32.1)  ...   POINT (-84.50667425 39.1050733)
# 24              30.7     (30.2, 31.3)  ...  POINT (-84.66255106 39.16433271)
# 25              34.8     (34.4, 35.2)  ...   POINT (-84.5983003 39.15636556)
# 26              31.1     (30.3, 31.8)  ...  POINT (-84.66572441 39.11814035)
# 27              23.2     (22.7, 23.8)  ...  POINT (-84.42664498 39.15301878)
# 28              36.4     (35.9, 36.8)  ...  POINT (-84.46193688 39.23527574)
# 29              32.5     (32.0, 33.1)  ...  POINT (-84.38542043 39.15388548)
# 30              35.8     (35.4, 36.3)  ...  POINT (-84.57520639 39.11003871)
# 31              35.8     (35.2, 36.3)  ...    POINT (-84.565155 39.17500144)
#
#    food_closest_travel_times  physical_closest_dist transport_closest_dist  \
# 0                  93.648000               0.425191               0.179313
# 1                 136.749800               0.500320               0.108970
# 2                 237.871775               0.224027               0.316975
# 3                 556.072600               0.096994               0.610498
# 4                 153.381550               0.301263               0.269021
# 5                 254.063220               0.319383               0.325493
# 6                 158.298600               0.396600               0.259841
# 7                 448.548675               0.247495               0.235043
# 8                 222.304570               0.308600               0.477728
# 9                 351.358090               0.228426               0.302160
# 10                111.019880               0.402707               0.397930
# 11                493.890840               0.209428               0.000263
# 12                240.566280               0.319383               0.484318
# 13                127.517960               0.208273               0.289292
# 14                168.642470               0.182064               0.121832
# 15                213.187290               0.431609               0.539707
# 16                264.824580               0.428865               0.361902
# 17                127.405490               0.357376               0.175638
# 18                127.517960               0.245801               0.456104
# 19                198.772105               0.239728               0.167556
# 20                264.381960               0.163584               0.353187
# 21                362.288600               0.227732               0.350905
# 22                203.411830               0.366465               0.144741
# 23                122.613580               0.173980               0.205188
# 24                133.906650               0.612130               0.149426
# 25                151.138170               0.406930               0.555563
# 26                889.789370               0.648989               0.130021
# 27                 65.126660               0.266233               0.166943
# 28                 27.575520               0.000277               0.165111
# 29                238.089630               0.000215               0.353187
# 30                133.957505               0.339146               0.171499
# 31                280.049070               0.121105               0.271972
#
#     education_closest_travel_times worship_closest_travel_times  \
# 0                       119.263740                   129.916700
# 1                        87.200000                    85.000000
# 2                        21.850000                    17.950000
# 3                        23.300000                   100.617800
# 4                        80.405235                    43.600000
# 5                        47.902393                    21.500000
# 6                       104.890050                    77.900000
# 7                        77.776440                    71.170740
# 8                       101.600784                    63.000000
# 9                        42.418995                    43.095461
# 10                       58.311523                    36.188576
# 11                      107.300000                   141.148380
# 12                       35.278675                    25.359606
# 13                       47.902393                    49.000170
# 14                       58.209955                    75.470924
# 15                       70.714702                    45.800000
# 16                       94.559297                    69.313825
# 17                       90.731870                    96.985195
# 18                       61.700000                    76.597910
# 19                       31.589337                    39.618090
# 20                       65.744150                    92.413880
# 21                       98.511086                   109.167790
# 22                       93.090750                    77.900000
# 23                       62.303438                    40.003351
# 24                      135.613400                    55.347057
# 25                      129.226230                    76.736365
# 26                       89.300000                    39.400000
# 27                       99.367920                    34.701141
# 28                       15.020617                    44.364110
# 29                       28.400000                    58.030277
# 30                       70.494098                    33.783306
# 31                       57.784384                    73.820610
#
#                 id Geographic Area Name  Household median income  \
# 0   8600000US45244          ZCTA5 45244                  97353.0
# 1   8600000US45232          ZCTA5 45232                  21877.0
# 2   8600000US45206          ZCTA5 45206                  40162.0
# 3   8600000US45239          ZCTA5 45239                  50863.0
# 4   8600000US45214          ZCTA5 45214                  20931.0
# 5   8600000US45229          ZCTA5 45229                  28454.0
# 6   8600000US45238          ZCTA5 45238                  53777.0
# 7   8600000US45224          ZCTA5 45224                  48647.0
# 8   8600000US45225          ZCTA5 45225                  16672.0
# 9   8600000US45207          ZCTA5 45207                  35713.0
# 10  8600000US45213          ZCTA5 45213                  62289.0
# 11  8600000US45231          ZCTA5 45231                  56774.0
# 12  8600000US45237          ZCTA5 45237                  38542.0
# 13  8600000US45219          ZCTA5 45219                  31177.0
# 14  8600000US45203          ZCTA5 45203                  21169.0
# 15  8600000US45217          ZCTA5 45217                  54811.0
# 16  8600000US45212          ZCTA5 45212                  45919.0
# 17  8600000US45230          ZCTA5 45230                  74548.0
# 18  8600000US45220          ZCTA5 45220                  40296.0
# 19  8600000US45216          ZCTA5 45216                  37125.0
# 20  8600000US45208          ZCTA5 45208                 116338.0
# 21  8600000US45226          ZCTA5 45226                  90195.0
# 22  8600000US45204          ZCTA5 45204                  39383.0
# 23  8600000US45202          ZCTA5 45202                  77927.0
# 24  8600000US45248          ZCTA5 45248                  75625.0
# 25  8600000US45211          ZCTA5 45211                  45419.0
# 26  8600000US45233          ZCTA5 45233                  86010.0
# 27  8600000US45209          ZCTA5 45209                  73206.0
# 28  8600000US45215          ZCTA5 45215                  55990.0
# 29  8600000US45227          ZCTA5 45227                  56661.0
# 30  8600000US45205          ZCTA5 45205                  29612.0
# 31  8600000US45223          ZCTA5 45223                  44865.0
#
#    Margin of error
# 0            10321
# 1             2712
# 2             8465
# 3             3281
# 4             5081
# 5             7876
# 6             3554
# 7             4337
# 8             2946
# 9             4171
# 10           10959
# 11            2494
# 12            4533
# 13            1398
# 14            6440
# 15           10115
# 16            4359
# 17            4300
# 18            5975
# 19            5464
# 20            9854
# 21            6495
# 22            4954
# 23            5272
# 24            4680
# 25            3690
# 26           11031
# 27           10132
# 28            4631
# 29            4231
# 30            2559
# 31            6822
#
# [32 rows x 72 columns]

# %% [markdown]
# ## Elastic Net

# %%
if all_deserts == True:
    desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']
    results = results_all_nan.copy()
    update_method = update_all_vars
else:
    desert_measures = ['food_closest_travel_times', 'physical_closest_dist']
    results = results_nan.copy()
    update_method = update_vars
if log_transf == True:
    df = tracts_health_logt
else:
    df = tracts_health
alphas = []
l1_ratios = []
i=0


for c in df.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        x = df[desert_measures+add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = df[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        data_centered = center_function(y)

        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)

        #l1 ratio is from suggested values in ElasticNetCV documentation
        enet_cv = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], 
                                     cv = 10, normalize=True).fit(X_train,y_train)

        alpha = enet_cv.alpha_
        l1 = enet_cv.l1_ratio_
        alphas.append(alpha)
        l1_ratios.append(l1)

        regr = ElasticNet(alpha=alpha, l1_ratio = l1, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))

        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)

        if all_deserts==True:
            update_all_vars()
        else:
            update_vars()

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0                          Mammograms  0.2173          -0.7886
# 1       Poor mental health prevalence  1.1942          -2.7121
# 2                   Cancer prevalence  0.0000           0.5343
# 3                   Core men's health -2.3269           6.1669
# 4                  Smoking prevalence  1.4210          -2.9801
# 5              Cholesterol screenings -0.0000           1.1851
# 6         High cholesterol prevalence  0.2949           0.4594
# 7                   Asthma prevalence  0.4054          -1.4555
# 8                  Obesity prevalence  1.4916          -4.9422
# 9          Cervical cancer screenings -0.0000           0.3048
# 10   Medium blood pressure prevalence  0.5679           0.1983
# 11               Arthritis prevalence  0.7898          -0.4202
# 12                   Routine checkups  0.7619          -1.6639
# 13            Health insurance access  2.2527          -3.3800
# 14              Poor sleep prevalence  1.2808          -4.2275
# 15                    Dental checkups -4.0966           7.7267
# 16              Teeth loss prevalence  1.0004          -4.8003
# 17     High blood pressure prevalence  1.8839          -3.9495
# 18          Binge drinking prevalence -0.8698           0.9035
# 19               No physical activity  2.3514          -4.3119
# 20              Depression prevalence -0.0032          -0.1174
# 21                Core women's health -2.1014           4.6800
# 22               Poor physical health  1.2268          -1.9525
# 23     General poor health prevalence  2.3831          -4.3403
# 24  Coronary heart disease prevalence  0.3135          -0.4069
# 25                    COPD prevalence  0.5590          -0.8388
# 26                Diabetes prevalence  1.0082          -2.1727
# 27             Chronic kidney disease  0.2355          -0.4902
# 28            Colon cancer screenings -2.6313           4.1958
# 29                  Stroke prevalence  0.3188          -0.7657
#
#     Public transport  Education  Houses of worship  RSquared         MSE
# 0            -0.3198    -0.1547           0.446637    0.5715    0.812013
# 1            -2.0779    -0.0370           2.359593    0.3319    8.105710
# 2             0.0000     0.0000           0.000000    0.2233    2.447715
# 3             5.1025     0.0000          -6.234011    0.2146   13.681497
# 4            -4.1822     0.2299           5.261401    0.1965    6.069259
# 5             0.3764     0.0528           0.000000    0.1647   34.858415
# 6             0.1760     0.6535           0.334879    0.1555   31.907988
# 7            -0.9667     0.0476           1.649222    0.1485    0.838952
# 8            -5.1141     0.4870           8.271425    0.0542   29.332406
# 9             0.8881     0.0000           0.000000    0.0298   73.500884
# 10           -0.1372     1.0269           0.951310   -0.0602  247.947429
# 11           -0.8719     1.0159           1.465508   -0.0733   27.661363
# 12           -0.7414     1.1243           2.309193   -0.1136   12.662604
# 13           -4.5543     0.7082           4.837110   -0.1165   17.730248
# 14           -4.2400     0.7061           6.523411   -0.1288   21.226600
# 15            7.8774    -1.5652          -9.073742   -0.1519   61.737437
# 16           -8.3237     0.1509           8.942452   -0.1826   26.689254
# 17           -4.7724     2.0447           6.980530   -0.3288   60.488507
# 18            1.3516    -0.9388          -1.781473   -0.3607    8.272836
# 19           -5.6127     1.4175           6.630957   -0.3899   34.002247
# 20           -0.1124    -0.3402          -0.022951   -0.4999    2.015138
# 21            5.1644     1.5729          -5.962461   -0.6252   20.532716
# 22           -2.5272     0.7399           2.786162   -0.7152    5.499661
# 23           -5.2854     1.5214           6.023961   -0.8786   23.424292
# 24           -0.5136     0.4625           0.529922   -0.8836    2.202104
# 25           -1.1507     0.4751           1.254659   -0.9071    1.873569
# 26           -2.7385     1.3535           3.416941   -1.0061   17.221880
# 27           -0.5000     0.3139           0.591168   -1.4553    0.844352
# 28            3.8580    -0.0000          -3.119367   -1.4588   18.382675
# 29           -0.8139     0.4761           0.995449   -1.5337    1.775504

# %% [markdown]
# ## LASSO

# %%
if all_deserts == True:
    desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']
    results = results_all_nan.copy()
    update_method = update_all_vars
else:
    desert_measures = ['food_closest_travel_times', 'physical_closest_dist']
    results = results_nan.copy()
    update_method = update_vars
if log_transf == True:
    df = tracts_health_logt
else:
    df = tracts_health
alphas = []
l1_ratios = []
i=0


for c in df.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = df[desert_measures+add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = df[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        if all_deserts==True:
            update_all_vars()
        else:
            update_vars()

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0                   Asthma prevalence  0.1735          -0.8330
# 1       Poor mental health prevalence  0.0351          -1.4097
# 2                     Dental checkups -2.1001           3.1627
# 3                   Core men's health -1.7230           4.1689
# 4               Poor sleep prevalence  0.5647          -1.9131
# 5                No physical activity  1.4879          -1.2748
# 6             Health insurance access  1.2617          -1.1389
# 7                          Mammograms  0.0000          -0.3955
# 8                  Smoking prevalence  0.9648          -1.2215
# 9                   Cancer prevalence  0.0820           0.1712
# 10             Cholesterol screenings  0.0000           0.7871
# 11                Core women's health -1.5622           3.2162
# 12        High cholesterol prevalence  0.2827           0.4087
# 13              Teeth loss prevalence  1.0552          -2.8739
# 14         Cervical cancer screenings  0.0000           0.0000
# 15                   Routine checkups  0.5582          -0.4954
# 16                 Obesity prevalence  1.6723          -3.0184
# 17   Medium blood pressure prevalence  0.3404           0.1828
# 18               Arthritis prevalence  0.2303           0.0192
# 19              Depression prevalence -0.0000          -0.1154
# 20          Binge drinking prevalence -0.3719           0.1422
# 21     High blood pressure prevalence  1.5732          -2.0054
# 22     General poor health prevalence  1.9059          -2.6450
# 23               Poor physical health  0.8903          -1.1311
# 24                Diabetes prevalence  0.7227          -1.0813
# 25                    COPD prevalence  0.3290          -0.4052
# 26             Chronic kidney disease  0.1317          -0.2340
# 27                  Stroke prevalence  0.1997          -0.3792
# 28  Coronary heart disease prevalence  0.0000          -0.0000
# 29            Colon cancer screenings -0.8026           1.5871
#
#     Public transport  Education  Houses of worship  RSquared         MSE
# 0            -0.9535     0.0000           1.255686    0.3451    0.645229
# 1            -2.3822    -0.0000           2.565178    0.2989    8.505751
# 2             9.5252    -0.0000          -8.993622    0.2807   38.552597
# 3             4.2052    -0.1271          -4.145545    0.2629   12.840901
# 4            -4.4327     0.5262           5.245035    0.2474   14.151897
# 5            -6.2818     0.0000           5.859538    0.2151   19.201334
# 6            -5.4394     0.0000           4.884732    0.1872   12.907359
# 7            -0.0000     0.0000           0.000000    0.1702    1.572563
# 8            -4.2895     0.0000           4.250716    0.1520    6.406008
# 9             0.1251     0.0237           0.007252    0.1230    2.763667
# 10            0.6202     0.2520          -0.000000    0.1183   36.794608
# 11            4.5016     0.8949          -4.432435    0.0924   11.466610
# 12            0.2019     0.2150           0.130371    0.0919   34.309350
# 13           -6.8697     0.0000           5.967150    0.0709   20.966848
# 14            1.0107     0.0000           0.000000    0.0145   74.659977
# 15           -0.0524     0.4818           0.734637   -0.0205   11.603895
# 16           -4.0858     0.5095           4.962265   -0.0206   31.652166
# 17            0.1369     0.2358           0.284995   -0.1149  260.738586
# 18            0.0398     0.1253           0.205256   -0.1668   30.071522
# 19           -0.0772    -0.3442           0.000000   -0.1770    1.581332
# 20            0.1459    -0.2430          -0.405021   -0.2099    7.355918
# 21           -1.6821     0.9163           2.365118   -0.2266   55.834767
# 22           -3.4414     0.4707           3.198257   -0.2785   15.941137
# 23           -1.3242     0.1940           1.230640   -0.4309    4.587962
# 24           -1.0021     0.4822           1.062642   -0.4672   12.595774
# 25           -0.3813     0.1035           0.378166   -0.6926    1.662877
# 26           -0.1715     0.0779           0.174279   -0.7519    0.602452
# 27           -0.2955     0.1331           0.301577   -0.7524    1.228045
# 28           -0.0000     0.0000           0.000000   -0.9801    2.314970
# 29            4.3732     0.0000          -3.446309   -1.0407   15.256767

# %%
if all_deserts == True:
    desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']
    results = results_all_nan.copy()
    update_method = update_all_vars
else:
    desert_measures = ['food_closest_travel_times', 'physical_closest_dist']
    results = results_nan.copy()
    update_method = update_vars
if log_transf == True:
    df = tracts_health_logt
else:
    df = tracts_health
alphas = []
l1_ratios = []
i=0


for c in df.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = df[desert_measures+add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = df[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(xscale, y.reshape(-1, 1))
        
        predictions = regr.predict(xscale)
        mse_test = mean_squared_error(y, predictions)
        
        if all_deserts==True:
            update_all_vars()
        else:
            update_vars()

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0                   Core men's health -1.1940           3.5721
# 1                 Core women's health -0.9995           2.7312
# 2               Teeth loss prevalence  1.0054          -2.4274
# 3                   Asthma prevalence  0.0310          -0.6930
# 4                     Dental checkups -1.6113           2.5298
# 5                  Smoking prevalence  0.7333          -0.9252
# 6               Poor sleep prevalence  0.0000          -1.3354
# 7             Health insurance access  1.2836          -0.7390
# 8       Poor mental health prevalence  0.2133          -1.0951
# 9                No physical activity  1.0844          -0.8845
# 10                         Mammograms  0.0000          -0.4438
# 11     General poor health prevalence  1.3245          -1.3069
# 12                 Obesity prevalence  0.5060          -2.1171
# 13               Poor physical health  0.7876          -0.4846
# 14             Cholesterol screenings  0.0000           0.6679
# 15     High blood pressure prevalence  0.8062          -1.3898
# 16                    COPD prevalence  0.4421          -0.2003
# 17         Cervical cancer screenings -0.0000           0.0000
# 18                  Cancer prevalence  0.0000           0.1487
# 19        High cholesterol prevalence  0.0000           0.4713
# 20                   Routine checkups  0.0000          -0.0000
# 21            Colon cancer screenings -0.6524           1.3036
# 22                Diabetes prevalence  0.3807          -0.6489
# 23   Medium blood pressure prevalence  0.0000           0.0000
# 24              Depression prevalence  0.0000          -0.0567
# 25               Arthritis prevalence  0.0000           0.0000
# 26          Binge drinking prevalence -0.0000          -0.0000
# 27             Chronic kidney disease  0.0000          -0.0000
# 28  Coronary heart disease prevalence  0.0000          -0.0000
# 29                  Stroke prevalence  0.0000          -0.0000
#
#     Public transport  Education  Houses of worship  RSquared         MSE
# 0             4.8541    -0.1963          -4.685410    0.5715   14.720126
# 1             4.7902     0.5845          -4.651810    0.5320   11.249901
# 2            -7.1614     0.0817           5.859983    0.4584   23.610178
# 3            -0.9372     0.0452           1.248946    0.4559    0.868392
# 4             9.1389    -0.5385          -8.233930    0.3077   52.127790
# 5            -4.2061     0.1543           3.962132    0.2993    8.567985
# 6            -4.4817     0.7097           5.219873    0.2852   15.956030
# 7            -5.5991     0.0000           4.671376    0.2807   15.153113
# 8            -2.4997     0.0000           2.386890    0.2623   11.185556
# 9            -6.1266     0.3395           5.451597    0.2505   24.301450
# 10           -0.0000     0.0000           0.000000    0.2298    1.491303
# 11           -5.6825     0.3229           4.757446    0.1608   19.627364
# 12           -4.5058     0.5637           5.491303    0.1562   31.488335
# 13           -2.6847     0.0632           2.096596    0.1203    5.363975
# 14            0.5442     0.0000          -0.000000    0.0370   37.475115
# 15           -3.8562     0.8437           4.446437    0.0017   52.593345
# 16           -1.2518     0.0188           0.923387   -0.0181    1.676470
# 17            0.8586     0.0000          -0.000000   -0.0353   70.693908
# 18            0.0000     0.0000           0.000000   -0.0382    3.273160
# 19            0.0000     0.0000           0.000000   -0.0645   37.200528
# 20            0.0000     0.1851           0.634142   -0.0934   12.598863
# 21            5.7485    -0.2754          -4.512200   -0.1292   18.154754
# 22           -2.4926     0.4710           2.296534   -0.1321   12.589216
# 23            0.0000     0.0000           0.000000   -0.1773  244.396992
# 24           -0.0640    -0.3310           0.000000   -0.1983    1.736873
# 25            0.0000     0.0000           0.000000   -0.2712   33.728398
# 26           -0.0000    -0.0000          -0.000000   -0.3648    9.619082
# 27           -0.0000     0.0000           0.000000   -0.5343    0.735210
# 28           -0.0000     0.0000           0.000000   -0.5381    2.171881
# 29           -0.0000     0.0000           0.000000   -0.5689    1.547496

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in zcta_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = np.log(zcta_health[desert_measures].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = zcta_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        y_test_pred = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, y_test_pred)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[1]
        results.iat[i, 2] = regr.coef_[3]
        results.iat[i, 3] = regr.coef_[4]
        results.iat[i, 4] = regr.coef_[0]
        results.iat[i, 5] = regr.coef_[2]
        results.iat[i, 6] = regr.score(X_test, y_test)
        results.iat[i, 7] = mse_test
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4}).sort_values(by='RSquared', ascending=False).reset_index(drop=True)
results_round
# Out:
#                      Health condition    Food  Physical health  \
# 0                   Core men's health -2.2131           5.5926
# 1                 Core women's health -1.2919           4.2951
# 2                   Asthma prevalence  0.0872          -1.3010
# 3                  Obesity prevalence  0.3527          -4.1558
# 4                Arthritis prevalence  0.0000          -0.0000
# 5                          Mammograms  0.0000          -0.4922
# 6               Teeth loss prevalence  0.5731          -4.6344
# 7                  Smoking prevalence  0.7061          -2.2584
# 8       Poor mental health prevalence  0.6725          -2.2438
# 9                   Cancer prevalence  0.0000           0.3481
# 10        High cholesterol prevalence  0.0000           0.9966
# 11                   Routine checkups  0.0000          -1.7494
# 12             Cholesterol screenings -0.0000           0.7910
# 13     High blood pressure prevalence  0.0000          -2.9193
# 14         Cervical cancer screenings  0.0000           0.0000
# 15   Medium blood pressure prevalence  0.0000           0.0000
# 16              Poor sleep prevalence  0.2146          -3.4082
# 17            Health insurance access  1.1084          -2.1468
# 18          Binge drinking prevalence -0.0804           0.1819
# 19               Poor physical health  0.4096          -1.2516
# 20                    Dental checkups -2.2509           6.1586
# 21            Colon cancer screenings -2.0037           4.0286
# 22                    COPD prevalence  0.1118          -0.4873
# 23               No physical activity  0.6248          -2.8088
# 24     General poor health prevalence  0.7804          -3.0843
# 25                Diabetes prevalence  0.0000          -1.4834
# 26  Coronary heart disease prevalence  0.0261          -0.2248
# 27              Depression prevalence  0.0000          -0.0000
# 28                  Stroke prevalence  0.0000          -0.6270
# 29             Chronic kidney disease  0.0000          -0.4141
#
#     Public transport  Education  Houses of worship  RSquared         MSE
# 0             4.7180    -0.0000          -5.248973    0.6026   13.652933
# 1             5.0076     0.5045          -5.656782    0.4962   12.110018
# 2            -1.0172     0.1846           1.847794    0.2428    1.208409
# 3            -5.2177     0.8631           8.435008    0.2118   29.415934
# 4            -2.0964     0.7079           2.971363    0.2069   21.042230
# 5            -0.0000    -0.0000           0.000000    0.1975    1.553940
# 6            -8.6742     1.2290           8.949850    0.1946   35.109009
# 7            -4.5791     0.6849           5.477235    0.1781   10.050061
# 8            -2.4454     0.3212           2.854491    0.1683   12.610833
# 9             0.0000     0.0000           0.000000    0.1169    2.784196
# 10            0.0000     0.5667           0.033401    0.1152   30.921879
# 11           -0.2539     1.0339           2.613932    0.1082   10.275933
# 12            0.4690    -0.0000           0.000000    0.0888   35.458193
# 13           -5.5561     2.0094           8.302422    0.0180   51.730780
# 14            0.7346    -0.0000           0.000000   -0.0422   71.165499
# 15            0.0000     0.0000           1.253168   -0.0523  218.439617
# 16           -4.4417     1.1018           6.893308   -0.0626   23.717660
# 17           -5.7088     0.9211           5.979351   -0.0800   22.751088
# 18            1.9368    -0.9764          -2.456113   -0.1047    7.785998
# 19           -3.2200     0.9045           3.473786   -0.1721    7.147403
# 20            9.2187    -2.4899         -10.511989   -0.1828   89.057922
# 21            4.0236    -0.4316          -3.404499   -0.2513   20.117523
# 22           -1.5761     0.5219           1.689228   -0.2689    2.089596
# 23           -6.6079     1.8120           7.735345   -0.2771   41.409004
# 24           -6.4019     1.9026           7.262374   -0.2840   30.030882
# 25           -3.2735     1.4080           4.072343   -0.4779   16.434055
# 26           -0.8726     0.5079           0.898182   -0.5077    2.129004
# 27           -0.1757    -0.3676          -0.000000   -0.5307    2.218626
# 28           -0.9927     0.4931           1.269177   -0.7293    1.705770
# 29           -0.6342     0.3411           0.816653   -0.7409    0.834204

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in zcta_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = np.log(zcta_health[desert_measures].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = zcta_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(xscale, y.reshape(-1, 1))
        
        y_pred = regr.predict(xscale)
        mse = mean_squared_error(y, y_pred)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[1]
        results.iat[i, 2] = regr.coef_[3]
        results.iat[i, 3] = regr.coef_[4]
        results.iat[i, 4] = regr.coef_[0]
        results.iat[i, 5] = regr.coef_[2]
        results.iat[i, 6] = regr.score(xscale, y)
        results.iat[i, 7] = mse
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4}).sort_values(by='RSquared', ascending=False).reset_index(drop=True)
results_round.to_csv(save_results_name)
results_round
# Out:
#                      Health condition    Food  Physical health  \
# 0                   Core men's health -1.6829           5.1211
# 1                  Obesity prevalence  0.0000          -2.6067
# 2               Teeth loss prevalence  1.1708          -4.3609
# 3                  Smoking prevalence  0.4613          -2.1146
# 4                   Asthma prevalence  0.0121          -1.0802
# 5                 Core women's health -0.8601           4.1036
# 6               Poor sleep prevalence  0.0550          -2.6178
# 7                     Dental checkups -2.8314           6.0390
# 8      General poor health prevalence  0.5241          -2.8172
# 9                No physical activity  0.7567          -2.7645
# 10     High blood pressure prevalence  0.0000          -1.4367
# 11               Poor physical health  0.2031          -1.1206
# 12                   Routine checkups  0.0000          -0.7334
# 13      Poor mental health prevalence  1.4491          -2.6763
# 14                Diabetes prevalence  0.0000          -0.9336
# 15            Health insurance access  1.4679          -2.6190
# 16          Binge drinking prevalence -0.0518           0.1987
# 17                  Stroke prevalence  0.0000          -0.3511
# 18                    COPD prevalence  0.0000          -0.3540
# 19             Chronic kidney disease  0.0000          -0.2278
# 20            Colon cancer screenings -2.5362           3.1188
# 21               Arthritis prevalence  0.0000          -0.0000
# 22             Cholesterol screenings -0.0000           1.6924
# 23        High cholesterol prevalence  0.0000           1.0655
# 24  Coronary heart disease prevalence  0.0000          -0.0518
# 25                  Cancer prevalence  0.0000           0.4713
# 26                         Mammograms  0.0000          -0.3742
# 27              Depression prevalence -0.0000          -0.2193
# 28   Medium blood pressure prevalence  0.0000           0.0000
# 29         Cervical cancer screenings -0.0000           0.9143
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0             3.4804     0.0000          -4.828722    0.6875  13.798901
# 1            -5.1042    -0.5588           8.484329    0.6793  13.822789
# 2            -6.7575    -0.3165           7.839691    0.6758  17.881753
# 3            -3.5536    -0.1231           5.111602    0.6622   6.702221
# 4            -0.7869    -0.0745           1.597257    0.6530   0.795431
# 5             3.5330     0.0000          -4.793430    0.6529  11.118410
# 6            -3.8688    -0.5209           6.458747    0.6330  10.266124
# 7             6.5712     0.3682          -8.312981    0.6092  39.697172
# 8            -4.8478    -0.0000           6.981239    0.6006  18.152815
# 9            -4.8001    -0.3773           6.983092    0.5934  19.576225
# 10           -5.5055    -0.0000           8.756887    0.5689  26.281826
# 11           -2.4601    -0.0000           3.476026    0.5675   5.019062
# 12           -0.5374     0.0000           2.925950    0.5526   4.817497
# 13           -1.1425    -0.0848           1.030061    0.5502   5.487369
# 14           -2.8672    -0.0000           4.282752    0.5400   7.792333
# 15           -3.5975    -0.1530           4.347651    0.5378  14.944976
# 16            1.3320     0.0000          -2.631038    0.5195   4.053879
# 17           -0.8980     0.0000           1.307386    0.5042   0.929571
# 18           -1.2552     0.0000           1.779368    0.4997   1.614796
# 19           -0.5646     0.0000           0.842746    0.4641   0.468370
# 20            2.3427     0.0000          -1.512674    0.4514  18.678156
# 21           -1.6824    -0.0000           3.676708    0.4179  12.481982
# 22            0.0000     0.0000           0.567260    0.3545  10.493477
# 23            0.0000     0.0000           0.987008    0.3373  14.149814
# 24           -0.7228     0.0000           1.050674    0.3360   1.428369
# 25            0.0000     0.0000           0.000000    0.2631   1.515185
# 26           -0.0000    -0.1112           0.000000    0.2433   1.416388
# 27           -0.0695     0.0000          -0.139639    0.2232   0.904789
# 28           -0.0000     0.0000           3.276805    0.2231  74.365946
# 29            0.0000     0.0000           0.796608    0.1713  21.566366
