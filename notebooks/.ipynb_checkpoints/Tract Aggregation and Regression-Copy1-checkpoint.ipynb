# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.linear_model import ElasticNet, ElasticNetCV, LassoCV, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler, RobustScaler, scale
import seaborn as sns

# %%
tracts_deserts_path = 'data/tract_desert_measures/nyc_desert_tracts.csv'
place_abbr = 'nyc'
save_data_name = 'data/tract_health' + place_abbr+'_tract_health.csv'
save_transf_data_name = 'data/tract_health' + place_abbr+'_tract_health_logt.csv'
save_results_name = 'data/tract_health/results' + place_abbr+'_tract_lasso_results.csv'

# %% [markdown]
# # Aggregation/Cleaning

# %%
tracts_deserts = pd.read_csv(tracts_deserts_path, dtype={'GEOID':'str'})
tracts_deserts = tracts_deserts.rename(columns={'GEOID':'TractFIPS'})

# %%
tracts_health = pd.read_csv("data/PLACES__Census_Tract_Data__GIS_Friendly_Format___2021_release.csv", dtype={'TractFIPS':'str'})
tracts_health = pd.merge(tracts_health, tracts_deserts, on='TractFIPS')
tracts_health.to_csv(save_data_name, index=False)

# %%
desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']

tracts_health_logt = tracts_health.copy()
tracts_health_logt[desert_measures] = tracts_health_logt[desert_measures].apply(lambda x: np.log(x+1))
tracts_health_logt.to_csv(save_transf_data_name, index=False)

# %%
#PovertyRate and MedianFamilyIncome in atlas

# %%
food_atlas = pd.read_excel('data/FoodAccessResearchAtlasData2019.xlsx', sheet_name = 'Food Access Research Atlas', dtype=str)

# %%
li = food_atlas[['CensusTract', 'LowIncomeTracts']].rename(columns={'CensusTract':'TractFIPS'}).astype({'LowIncomeTracts':int})
tracts_health_li = pd.merge(tracts_health, li, on='TractFIPS')

# %%
li.to_csv('li_tracts.csv', index=False)

# %%
income_vars = food_atlas[['CensusTract', 'LowIncomeTracts', 'PovertyRate', 'MedianFamilyIncome']] \
.rename(columns={'CensusTract':'TractFIPS'}).astype({'LowIncomeTracts':int, 'MedianFamilyIncome':'float', 'PovertyRate':'float'})

# %%
income_vars.to_csv('data/tract_incomevars.csv', index=False)

# %%
tracts_health = pd.merge(tracts_health, income_vars, on='TractFIPS')

# %%
plt.hist(tracts_health.PovertyRate, bins=40)
# Out:
# (array([ 44., 131., 200., 222., 195., 187., 154., 154., 116., 109.,  80.,
#          85.,  73.,  66.,  59.,  38.,  35.,  30.,  37.,  28.,  23.,  13.,
#          14.,   7.,   4.,   4.,   3.,   1.,   0.,   0.,   1.,   2.,   0.,
#           0.,   0.,   0.,   0.,   1.,   0.,   1.]),
#  array([ 0.        ,  2.29007634,  4.58015267,  6.87022901,  9.16030534,
#         11.45038168, 13.74045802, 16.03053435, 18.32061069, 20.61068702,
#         22.90076336, 25.19083969, 27.48091603, 29.77099237, 32.0610687 ,
#         34.35114504, 36.64122137, 38.93129771, 41.22137405, 43.51145038,
#         45.80152672, 48.09160305, 50.38167939, 52.67175573, 54.96183206,
#         57.2519084 , 59.54198473, 61.83206107, 64.1221374 , 66.41221374,
#         68.70229008, 70.99236641, 73.28244275, 75.57251908, 77.86259542,
#         80.15267176, 82.44274809, 84.73282443, 87.02290076, 89.3129771 ,
#         91.60305344]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# # Analysis

# %%
name_mapping = {'access2': 'Health insurance access', 'arthritis': 'Arthritis prevalence', 'binge': 'Binge drinking prevalence',
               'bphigh': 'High blood pressure prevalence', 'bpmed': 'Medium blood pressure prevalence', 'cancer': 'Cancer prevalence',
               'casthma': 'Asthma prevalence', 'cervical': 'Cervical cancer screenings', 'chd': 'Coronary heart disease prevalence',
               'checkup': 'Routine checkups', 'cholscreen': 'Cholesterol screenings', 'colon_screen': 'Colon cancer screenings',
               'copd': 'COPD prevalence', 'corem': 'Core men\'s health', 'corew': 'Core women\'s health', 'csmoking': 'Smoking prevalence',
               'dental': 'Dental checkups', 'depression': 'Depression prevalence', 'diabetes': 'Diabetes prevalence', 'ghlth': 'General poor health prevalence',
               'highchol': 'High cholesterol prevalence', 'kidney': 'Chronic kidney disease', 'lpa': 'No physical activity', 'mammouse': 'Mammograms',
               'mhlth': 'Poor mental health prevalence', 'obesity': 'Obesity prevalence', 'phlth': 'Poor physical health', 'sleep': 'Poor sleep prevalence',
               'stroke': 'Stroke prevalence', 'teethlost': 'Teeth loss prevalence'}

results_nan = pd.DataFrame({'Health condition': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')], 'Food': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')],
                       'Physical health': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')], 'Public transport': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')],
                        'Education': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')], 'Houses of worship': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')],
                       'Poverty Rate': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')], 'RSquared': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')], 
                            'MSE': [np.nan for c in tracts_health.columns if c.endswith('CrudePrev')]})
add_vars = ['PovertyRate']

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in tracts_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = tracts_health[desert_measures+add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = tracts_health_logt[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        data_centered = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        enet_cv = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], 
                                     cv = 10, normalize=True).fit(X_train,y_train)
        
        alpha = enet_cv.alpha_
        l1 = enet_cv.l1_ratio_
        alphas.append(alpha)
        l1_ratios.append(l1)
        
        regr = ElasticNet(alpha=alpha, l1_ratio = l1, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[0]
        results.iat[i, 2] = regr.coef_[1]
        results.iat[i, 3] = regr.coef_[2]
        results.iat[i, 4] = regr.coef_[3]
        results.iat[i, 5] = regr.coef_[4]
        results.iat[i, 6] = regr.coef_[5]
        results.iat[i, 7] = regr.score(X_test, y_test)
        results.iat[i, 8] = mse_test
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0       Poor mental health prevalence  0.1871           0.2144
# 1               Teeth loss prevalence  0.2756           0.8351
# 2                Poor physical health  0.2375           0.3067
# 3      General poor health prevalence  0.4533           0.5387
# 4                  Smoking prevalence  0.3958           0.5042
# 5                     Dental checkups -0.1847          -1.3078
# 6                No physical activity  0.7224           1.0468
# 7             Colon cancer screenings -0.0000          -0.6770
# 8             Health insurance access  0.0000           0.4613
# 9                     COPD prevalence  0.1240           0.2320
# 10             Chronic kidney disease  0.0573           0.0537
# 11                Core women's health  0.2104          -0.5871
# 12                  Core men's health -0.0086          -0.5389
# 13                 Obesity prevalence  1.4328           0.5961
# 14             Cholesterol screenings  0.1833           0.0019
# 15                Diabetes prevalence  0.3458           0.3869
# 16                  Asthma prevalence  0.2840           0.0348
# 17                  Stroke prevalence  0.0916           0.1249
# 18              Poor sleep prevalence  0.6620           0.7532
# 19         Cervical cancer screenings  0.6294          -0.3329
# 20  Coronary heart disease prevalence  0.0799           0.1212
# 21     High blood pressure prevalence  0.9782           0.8890
# 22                  Cancer prevalence  0.0873           0.0071
# 23              Depression prevalence -0.1007          -0.3408
# 24          Binge drinking prevalence -0.3802          -0.6494
# 25                   Routine checkups  0.6236           0.2156
# 26               Arthritis prevalence  0.5305           0.2387
# 27   Medium blood pressure prevalence  0.4924           0.6057
# 28                         Mammograms  0.0941          -0.2367
# 29        High cholesterol prevalence  0.1460           0.1267
#
#     Public transport  Education  Houses of worship  Poverty Rate  RSquared  \
# 0             0.1097    -0.0518           0.060691      2.446118    0.7279
# 1             0.3126    -0.0000          -0.000000      6.176477    0.7102
# 2             0.3200    -0.0778           0.096094      2.945439    0.6969
# 3             0.3278    -0.0000          -0.000000      6.209147    0.6644
# 4             0.2956    -0.0825           0.147919      3.200450    0.6636
# 5            -0.3464    -0.0831           0.180886     -8.055115    0.6338
# 6             0.6149    -0.0000          -0.000000      6.271017    0.5663
# 7            -0.1042    -0.0318          -0.021927     -5.328833    0.5415
# 8            -0.0000     0.0996          -0.179883      5.525079    0.5388
# 9             0.2958    -0.0956           0.161376      1.338883    0.4990
# 10            0.0887    -0.0184          -0.000000      0.608730    0.4810
# 11           -0.0157    -0.1082           0.254066     -2.769314    0.4759
# 12           -0.1721    -0.1034           0.176260     -3.369865    0.4645
# 13            0.6036    -0.0454          -0.342387      3.612124    0.4242
# 14            0.1880    -0.0000          -0.121132     -2.011070    0.4213
# 15            0.3331    -0.0074          -0.086665      2.300974    0.4138
# 16            0.0804    -0.0610          -0.039694      1.003435    0.4124
# 17            0.1395    -0.0272          -0.000000      0.692601    0.3681
# 18            0.2159     0.0000          -0.219482      2.470778    0.3397
# 19           -0.0000    -0.0556          -0.168569     -2.774564    0.3056
# 20            0.2517    -0.0659           0.127882      0.918193    0.2769
# 21            0.9274    -0.1819          -0.159867      2.665571    0.2300
# 22            0.2400    -0.0725           0.135450     -0.447481    0.1745
# 23           -0.1256    -0.0885           0.244287      0.699873    0.1385
# 24           -0.5617     0.0000           0.000000     -1.093585    0.1151
# 25            0.4394    -0.0634          -0.158716     -0.800583    0.1096
# 26            0.6977    -0.2149           0.298930      0.885661    0.1066
# 27            0.8038    -0.1275          -0.000000      0.000000    0.0427
# 28           -0.2744    -0.0778          -0.198806     -0.050896    0.0266
# 29            0.4398    -0.0547           0.257248      0.126877    0.0206
#
#           MSE
# 0    2.432075
# 1   14.504861
# 2    3.816562
# 3   20.739776
# 4    5.966374
# 5   40.819912
# 6   31.430032
# 7   26.725765
# 8   27.891553
# 9    1.744573
# 10   0.353891
# 11   7.351195
# 12  10.349365
# 13  23.026878
# 14   6.254793
# 15   7.484624
# 16   1.784390
# 17   0.749916
# 18  14.441320
# 19  13.458224
# 20   1.945038
# 21  27.140637
# 22   2.197573
# 23   4.639958
# 24  11.714685
# 25   9.880723
# 26  12.706127
# 27  25.650182
# 28   8.514180
# 29  13.358401

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in tracts_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = tracts_health[add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = tracts_health_logt[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        data_centered = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        enet_cv = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], 
                                     cv = 10, normalize=True).fit(X_train,y_train)
        
        alpha = enet_cv.alpha_
        l1 = enet_cv.l1_ratio_
        alphas.append(alpha)
        l1_ratios.append(l1)
        
        regr = ElasticNet(alpha=alpha, l1_ratio = l1, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        results.iat[i, 0] = name
        #results.iat[i, 1] = regr.coef_[0]
        #results.iat[i, 2] = regr.coef_[1]
        #results.iat[i, 3] = regr.coef_[2]
        #results.iat[i, 4] = regr.coef_[3]
        #results.iat[i, 5] = regr.coef_[4]
        results.iat[i, 6] = regr.coef_[0]
        results.iat[i, 7] = regr.score(X_test, y_test)
        results.iat[i, 8] = mse_test
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition  Food  Physical health  \
# 0       Poor mental health prevalence   NaN              NaN
# 1               Teeth loss prevalence   NaN              NaN
# 2                Poor physical health   NaN              NaN
# 3      General poor health prevalence   NaN              NaN
# 4                     Dental checkups   NaN              NaN
# 5                  Smoking prevalence   NaN              NaN
# 6                No physical activity   NaN              NaN
# 7             Health insurance access   NaN              NaN
# 8             Colon cancer screenings   NaN              NaN
# 9              Chronic kidney disease   NaN              NaN
# 10                Core women's health   NaN              NaN
# 11                  Core men's health   NaN              NaN
# 12                    COPD prevalence   NaN              NaN
# 13             Cholesterol screenings   NaN              NaN
# 14                Diabetes prevalence   NaN              NaN
# 15                  Asthma prevalence   NaN              NaN
# 16                 Obesity prevalence   NaN              NaN
# 17                  Stroke prevalence   NaN              NaN
# 18              Poor sleep prevalence   NaN              NaN
# 19         Cervical cancer screenings   NaN              NaN
# 20  Coronary heart disease prevalence   NaN              NaN
# 21     High blood pressure prevalence   NaN              NaN
# 22                  Cancer prevalence   NaN              NaN
# 23              Depression prevalence   NaN              NaN
# 24                   Routine checkups   NaN              NaN
# 25          Binge drinking prevalence   NaN              NaN
# 26               Arthritis prevalence   NaN              NaN
# 27   Medium blood pressure prevalence   NaN              NaN
# 28        High cholesterol prevalence   NaN              NaN
# 29                         Mammograms   NaN              NaN
#
#     Public transport  Education  Houses of worship  Poverty Rate  RSquared  \
# 0                NaN        NaN                NaN  2.409033e+00    0.7117
# 1                NaN        NaN                NaN  6.051611e+00    0.6828
# 2                NaN        NaN                NaN  2.863519e+00    0.6781
# 3                NaN        NaN                NaN  6.162277e+00    0.6548
# 4                NaN        NaN                NaN -7.817854e+00    0.6247
# 5                NaN        NaN                NaN  3.098715e+00    0.6229
# 6                NaN        NaN                NaN  6.123986e+00    0.5413
# 7                NaN        NaN                NaN  5.492926e+00    0.5334
# 8                NaN        NaN                NaN -5.283708e+00    0.5296
# 9                NaN        NaN                NaN  5.942031e-01    0.4691
# 10               NaN        NaN                NaN -2.648746e+00    0.4571
# 11               NaN        NaN                NaN -3.240152e+00    0.4505
# 12               NaN        NaN                NaN  1.266419e+00    0.4357
# 13               NaN        NaN                NaN -2.041204e+00    0.4162
# 14               NaN        NaN                NaN  2.230890e+00    0.3995
# 15               NaN        NaN                NaN  1.018085e+00    0.3744
# 16               NaN        NaN                NaN  3.586936e+00    0.3562
# 17               NaN        NaN                NaN  6.647156e-01    0.3450
# 18               NaN        NaN                NaN  2.402262e+00    0.3181
# 19               NaN        NaN                NaN -2.677624e+00    0.2708
# 20               NaN        NaN                NaN  8.661464e-01    0.2315
# 21               NaN        NaN                NaN  2.507632e+00    0.1816
# 22               NaN        NaN                NaN -4.870517e-01    0.1338
# 23               NaN        NaN                NaN  8.151353e-01    0.1215
# 24               NaN        NaN                NaN -8.707197e-01    0.0722
# 25               NaN        NaN                NaN -9.690171e-01    0.0670
# 26               NaN        NaN                NaN  7.983634e-01    0.0256
# 27               NaN        NaN                NaN -1.194151e-01    0.0017
# 28               NaN        NaN                NaN  0.000000e+00   -0.0007
# 29               NaN        NaN                NaN  2.940157e-19   -0.0024
#
#           MSE
# 0    2.577386
# 1   15.874310
# 2    4.053684
# 3   21.329733
# 4   41.829149
# 5    6.688317
# 6   33.239892
# 7   28.218715
# 8   27.415928
# 9    0.361976
# 10   7.614639
# 11  10.619981
# 12   1.965112
# 13   6.309455
# 14   7.667791
# 15   1.899562
# 16  25.749054
# 17   0.777379
# 18  14.912756
# 19  14.133516
# 20   2.067087
# 21  28.847483
# 22   2.305701
# 23   4.731751
# 24  10.295599
# 25  12.350861
# 26  13.858220
# 27  26.749907
# 28  13.649136
# 29   8.767779

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in tracts_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = tracts_health[desert_measures+add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = tracts_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[0]
        results.iat[i, 2] = regr.coef_[1]
        results.iat[i, 3] = regr.coef_[2]
        results.iat[i, 4] = regr.coef_[3]
        results.iat[i, 5] = regr.coef_[4]
        results.iat[i, 6] = regr.coef_[5]
        results.iat[i, 7] = regr.score(X_test, y_test)
        results.iat[i, 8] = mse_test

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0               Teeth loss prevalence  0.3141           0.8545
# 1       Poor mental health prevalence  0.1764           0.1808
# 2                Poor physical health  0.2208           0.3004
# 3      General poor health prevalence  0.4628           0.5824
# 4                  Smoking prevalence  0.3831           0.4380
# 5                     Dental checkups -0.1262          -1.3004
# 6                No physical activity  0.7305           1.0820
# 7             Colon cancer screenings  0.0000          -0.6603
# 8             Health insurance access -0.0000           0.4511
# 9                     COPD prevalence  0.1206           0.2504
# 10                Core women's health  0.1638          -0.5588
# 11                  Core men's health -0.0000          -0.5806
# 12             Chronic kidney disease  0.0624           0.0687
# 13                 Obesity prevalence  1.4535           0.5716
# 14                Diabetes prevalence  0.3324           0.4053
# 15             Cholesterol screenings  0.2159           0.0297
# 16                  Asthma prevalence  0.2946           0.0340
# 17                  Stroke prevalence  0.0995           0.1454
# 18              Poor sleep prevalence  0.7008           0.7332
# 19         Cervical cancer screenings  0.6383          -0.3070
# 20  Coronary heart disease prevalence  0.0777           0.1502
# 21     High blood pressure prevalence  1.0236           0.9698
# 22                  Cancer prevalence  0.0837           0.0284
# 23              Depression prevalence -0.0950          -0.3455
# 24          Binge drinking prevalence -0.4101          -0.6891
# 25               Arthritis prevalence  0.5429           0.3010
# 26                   Routine checkups  0.6823           0.2524
# 27   Medium blood pressure prevalence  0.5457           0.7181
# 28                         Mammograms  0.1417          -0.3000
# 29        High cholesterol prevalence  0.1281           0.1994
#
#     Public transport  Education  Houses of worship  Poverty Rate  RSquared  \
# 0             0.3465    -0.0242          -0.040343      6.154032    0.7223
# 1             0.0949    -0.0000           0.035883      2.472601    0.6959
# 2             0.2616    -0.0000           0.100378      2.908314    0.6919
# 3             0.2993     0.0166          -0.000000      6.229717    0.6621
# 4             0.2472    -0.0000           0.108000      3.186954    0.6525
# 5            -0.2109    -0.1870           0.035415     -8.062390    0.6212
# 6             0.5590     0.0833           0.000000      6.314355    0.5657
# 7            -0.0622    -0.1461          -0.000227     -5.387645    0.5300
# 8            -0.0000     0.1892          -0.185304      5.590307    0.5294
# 9             0.2720    -0.0785           0.187726      1.305421    0.4871
# 10           -0.0056    -0.0881           0.214527     -2.742328    0.4769
# 11           -0.1375    -0.0943           0.156890     -3.381186    0.4739
# 12            0.0774    -0.0181           0.009405      0.589075    0.4705
# 13            0.5193     0.0000          -0.266620      3.588702    0.4233
# 14            0.2536     0.0000          -0.002667      2.215804    0.4215
# 15            0.1721    -0.0268          -0.107164     -2.063629    0.3968
# 16            0.0844    -0.0625          -0.036955      1.033222    0.3889
# 17            0.1203    -0.0229           0.011702      0.660443    0.3620
# 18            0.1761     0.0000          -0.192023      2.482067    0.3256
# 19           -0.0219    -0.0254          -0.198408     -2.784174    0.3051
# 20            0.2197    -0.0624           0.164045      0.845736    0.2639
# 21            0.8587    -0.1601          -0.065624      2.644602    0.2473
# 22            0.2350    -0.0911           0.169464     -0.472336    0.1351
# 23           -0.0642    -0.1175           0.228932      0.761510    0.1192
# 24           -0.5348    -0.0056          -0.000000     -1.105366    0.1124
# 25            0.6874    -0.2430           0.394732      0.859241    0.1049
# 26            0.4067    -0.0584          -0.142812     -0.861659    0.0981
# 27            0.8066    -0.2077           0.099644     -0.013324    0.0358
# 28           -0.3475    -0.0676          -0.270032     -0.106057    0.0181
# 29            0.4806    -0.1009           0.382569      0.115245    0.0063
#
#           MSE
# 0   13.946731
# 1    2.628211
# 2    4.066150
# 3   21.132864
# 4    5.953743
# 5   41.692048
# 6   31.551564
# 7   26.699045
# 8   27.805616
# 9    2.131502
# 10   7.131982
# 11  10.740496
# 12   0.460749
# 13  22.618563
# 14   8.257236
# 15   6.383389
# 16   1.772585
# 17   1.027803
# 18  14.367125
# 19  13.638594
# 20   3.090255
# 21  28.185811
# 22   2.332654
# 23   4.611275
# 24  12.025085
# 25  13.756341
# 26   9.764779
# 27  26.208097
# 28   8.596444
# 29  14.249933

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in tracts_health_logt.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = np.log(tracts_health[desert_measures+add_vars].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = tracts_health_logt[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[0]
        results.iat[i, 2] = regr.coef_[1]
        results.iat[i, 3] = regr.coef_[2]
        results.iat[i, 4] = regr.coef_[3]
        results.iat[i, 5] = regr.coef_[4]
        results.iat[i, 6] = regr.coef_[5]
        results.iat[i, 7] = regr.score(X_test, y_test)
        results.iat[i, 8] = mse_test

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0       Poor mental health prevalence  0.3401           0.0647
# 1               Teeth loss prevalence  0.7695           0.5169
# 2                     Dental checkups -0.7873          -1.0399
# 3      General poor health prevalence  1.0054           0.3189
# 4                  Smoking prevalence  0.5546           0.3159
# 5                Poor physical health  0.4692           0.1612
# 6                No physical activity  1.2160           0.8395
# 7                   Core men's health -0.3482          -0.4158
# 8             Colon cancer screenings -0.2633          -0.6528
# 9             Health insurance access  0.5084           0.3137
# 10                Core women's health -0.1421          -0.4930
# 11                 Obesity prevalence  1.5447           0.3690
# 12             Cholesterol screenings  0.1085           0.0686
# 13                Diabetes prevalence  0.5770           0.2714
# 14                    COPD prevalence  0.2307           0.1466
# 15             Chronic kidney disease  0.1282           0.0254
# 16              Poor sleep prevalence  0.7603           0.6536
# 17                  Asthma prevalence  0.3153          -0.0280
# 18         Cervical cancer screenings  0.1941          -0.1865
# 19                  Stroke prevalence  0.1771           0.0897
# 20     High blood pressure prevalence  1.2718           0.6813
# 21                  Cancer prevalence  0.0416           0.0000
# 22  Coronary heart disease prevalence  0.1680           0.0743
# 23          Binge drinking prevalence -0.4555          -0.6402
# 24              Depression prevalence -0.0906          -0.3955
# 25                   Routine checkups  0.5740           0.1747
# 26               Arthritis prevalence  0.5651           0.1218
# 27   Medium blood pressure prevalence  0.5398           0.5613
# 28                         Mammograms  0.1011          -0.3099
# 29        High cholesterol prevalence  0.1305           0.0640
#
#     Public transport  Education  Houses of worship  Poverty Rate  RSquared  \
# 0             0.1210    -0.0000           0.049707      2.234975    0.5545
# 1             0.4398     0.0000           0.000000      5.636768    0.5384
# 2            -0.4532    -0.3548           0.000000     -7.789350    0.5052
# 3             0.3924     0.1444           0.055411      5.761490    0.5036
# 4             0.3408     0.0275           0.113874      2.986640    0.5012
# 5             0.2943     0.0547           0.142998      2.639529    0.4981
# 6             0.7434     0.4035           0.093231      6.088556    0.4662
# 7            -0.1244    -0.1932           0.194029     -3.348103    0.4574
# 8            -0.3405    -0.2449          -0.186491     -5.465147    0.4457
# 9             0.0000     0.1830          -0.082567      5.325197    0.4380
# 10           -0.0851    -0.0739           0.083978     -2.817682    0.4038
# 11            0.6676     0.2692          -0.310638      3.366295    0.3293
# 12            0.1404     0.0570          -0.120151     -1.961463    0.3265
# 13            0.2882     0.1453           0.000000      2.065019    0.3173
# 14            0.2561     0.0177           0.161652      1.133347    0.3141
# 15            0.0692     0.0106           0.013448      0.514263    0.3115
# 16            0.3421     0.2159          -0.240417      2.592251    0.3058
# 17            0.0517    -0.0176          -0.010256      0.862540    0.2964
# 18           -0.0000     0.0000          -0.146360     -2.663228    0.2902
# 19            0.1113     0.0270           0.016141      0.580321    0.2317
# 20            0.8234     0.2319          -0.042728      2.373765    0.1817
# 21            0.1937     0.0000           0.110301     -0.508674    0.1562
# 22            0.2018     0.0187           0.136397      0.722196    0.1465
# 23           -0.6187    -0.3458          -0.089025     -1.246425    0.1268
# 24           -0.1184    -0.2353           0.190476      0.538723    0.0967
# 25            0.3670     0.1569          -0.098448     -0.871815    0.0922
# 26            0.6183     0.0459           0.293983      0.600292    0.0612
# 27            0.7206     0.1640           0.077120      0.000000    0.0428
# 28           -0.3470    -0.0807          -0.305807     -0.158578    0.0291
# 29            0.3977     0.0316           0.308101     -0.000000    0.0115
#
#           MSE
# 0    3.850881
# 1   23.183398
# 2   54.468033
# 3   31.050311
# 4    8.546953
# 5    6.624192
# 6   38.774240
# 7   11.077689
# 8   31.488198
# 9   33.209304
# 10   8.128123
# 11  26.308775
# 12   7.127368
# 13   9.744924
# 14   2.850314
# 15   0.599100
# 16  14.789409
# 17   2.041089
# 18  13.931386
# 19   1.237794
# 20  30.639914
# 21   2.275651
# 22   3.582920
# 23  11.831031
# 24   4.728798
# 25   9.828503
# 26  14.427686
# 27  26.018440
# 28   8.500771
# 29  14.175207

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in tracts_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = tracts_health[desert_measures+add_vars].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = tracts_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(xscale,y)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(xscale, y.reshape(-1, 1))
        
        predictions = regr.predict(xscale)
        mse_test = mean_squared_error(y, predictions)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[0]
        results.iat[i, 2] = regr.coef_[1]
        results.iat[i, 3] = regr.coef_[2]
        results.iat[i, 4] = regr.coef_[3]
        results.iat[i, 5] = regr.coef_[4]
        results.iat[i, 6] = regr.coef_[5]
        results.iat[i, 7] = regr.score(X_test, y_test)
        results.iat[i, 8] = mse_test

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4}).sort_values(by='RSquared', ascending=False).reset_index(drop=True)
results_round.to_csv(save_results_name)
results_round
# Out:
#                      Health condition    Food  Physical health  \
# 0               Teeth loss prevalence  0.3192           0.8113
# 1             Health insurance access  0.0169           0.4641
# 2      General poor health prevalence  0.5122           0.5347
# 3                No physical activity  0.7202           1.0024
# 4                  Obesity prevalence  1.5020           0.5391
# 5                  Smoking prevalence  0.4214           0.4849
# 6                Poor physical health  0.2543           0.2860
# 7               Poor sleep prevalence  0.6283           0.6524
# 8      High blood pressure prevalence  0.9541           0.7280
# 9       Poor mental health prevalence  0.2066           0.2110
# 10                Diabetes prevalence  0.3419           0.3314
# 11                    COPD prevalence  0.1299           0.2301
# 12                  Asthma prevalence  0.3009           0.0239
# 13  Coronary heart disease prevalence  0.0621           0.1000
# 14               Arthritis prevalence  0.5630           0.2002
# 15              Depression prevalence -0.0588          -0.3085
# 16                  Stroke prevalence  0.0774           0.0879
# 17             Chronic kidney disease  0.0559           0.0405
# 18        High cholesterol prevalence  0.1448           0.0832
# 19                         Mammograms  0.0271          -0.2237
# 20   Medium blood pressure prevalence  0.4368           0.4884
# 21                  Cancer prevalence  0.0928           0.0000
# 22                   Routine checkups  0.6453           0.1373
# 23          Binge drinking prevalence -0.3322          -0.5647
# 24             Cholesterol screenings  0.1708          -0.0000
# 25         Cervical cancer screenings  0.6822          -0.4322
# 26                Core women's health  0.1414          -0.5083
# 27                  Core men's health -0.0000          -0.4564
# 28            Colon cancer screenings  0.0454          -0.7652
# 29                    Dental checkups -0.1375          -1.2235
#
#     Public transport  Education  Houses of worship  Poverty Rate  RSquared  \
# 0             0.3114    -0.0000          -0.000000      6.067594    0.5176
# 1            -0.0671     0.1961          -0.241631      5.529032    0.5172
# 2             0.3124     0.0000          -0.036539      6.236827    0.5154
# 3             0.5907     0.0000          -0.000000      6.269170    0.5113
# 4             0.6161    -0.1247          -0.244296      3.674532    0.4854
# 5             0.2768    -0.0784           0.203985      3.238391    0.4653
# 6             0.2903    -0.0474           0.088984      2.931345    0.4381
# 7             0.1838    -0.0000          -0.136993      2.498312    0.3990
# 8             0.8241    -0.0747          -0.080790      2.637228    0.3981
# 9             0.0962    -0.0644           0.086482      2.455271    0.3904
# 10            0.3073     0.0031          -0.095439      2.279184    0.3736
# 11            0.2872    -0.0788           0.171522      1.327850    0.2388
# 12            0.0693    -0.0757          -0.012839      1.010481    0.1959
# 13            0.2284    -0.0000           0.105829      0.881969    0.1665
# 14            0.6986    -0.2040           0.301113      0.860379    0.1576
# 15           -0.1131    -0.1338           0.248279      0.733935    0.1311
# 16            0.1070    -0.0000           0.000000      0.657124    0.1289
# 17            0.0758    -0.0052          -0.000000      0.589797    0.1162
# 18            0.4542    -0.0000           0.192893      0.079623    0.0130
# 19           -0.2337    -0.0118          -0.168320      0.000000   -0.0006
# 20            0.7709    -0.0622          -0.000000     -0.000000   -0.0125
# 21            0.2343    -0.0608           0.128282     -0.469133   -0.1024
# 22            0.4240    -0.0549          -0.155066     -0.832511   -0.1800
# 23           -0.5397    -0.0000           0.000000     -1.053339   -0.2639
# 24            0.1698    -0.0134          -0.105804     -2.007753   -0.4931
# 25            0.0454    -0.0894          -0.201812     -2.731544   -0.6991
# 26           -0.0000    -0.0387           0.225800     -2.680509   -0.6998
# 27           -0.0113    -0.0000           0.132919     -3.184380   -0.8649
# 28           -0.1199    -0.1318          -0.047666     -5.447087   -1.7207
# 29           -0.2432    -0.1725           0.191896     -8.094392   -3.0058
#
#           MSE
# 0   16.063221
# 1   25.652784
# 2   20.983486
# 3   31.049411
# 4   22.946857
# 5    5.619066
# 6    4.163958
# 7   14.250033
# 8   28.682455
# 9    2.390240
# 10   7.985511
# 11   1.999835
# 12   1.738624
# 13   2.204764
# 14  13.280045
# 15   4.521598
# 16   0.891427
# 17   0.413643
# 18  13.852554
# 19   9.001643
# 20  24.852681
# 21   2.109916
# 22   9.633064
# 23  11.696045
# 24   5.837792
# 25  15.090530
# 26   7.485431
# 27  11.143661
# 28  25.979156
# 29  41.932263
