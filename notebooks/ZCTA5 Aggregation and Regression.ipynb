# %%
import h5py
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.linear_model import ElasticNet, LinearRegression, Ridge, ElasticNetCV, LassoCV, Lasso
from sklearn.model_selection import GridSearchCV, KFold, train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler, RobustScaler, scale
from distfit import distfit
from sklearn.decomposition import PCA
from scipy.stats import boxcox 
import seaborn as sns 
from haversine import haversine

# %%
tracts_deserts = pd.read_csv('nyc_desert_tracts.csv', dtype={'GEOID':'str'})
tracts_deserts
# Out:
#       food_closest_travel_times  physical_closest_dist  \
# 0                    241.000061               0.000338
# 1                    279.976196               0.282170
# 2                    293.006378               0.273411
# 3                    155.181366               0.247503
# 4                    124.599907               0.048832
# ...                         ...                    ...
# 2163                  40.582970               0.353592
# 2164                  83.954140               0.232066
# 2165                 137.402847               0.318557
# 2166                 189.980087               0.411144
# 2167                 171.557739               0.556813
#
#       transport_closest_dist  education_closest_travel_times  \
# 0                   0.000338                      228.306671
# 1                   0.307877                       60.904408
# 2                   0.194327                       66.519920
# 3                   0.087596                       20.076658
# 4                   0.286151                      108.333473
# ...                      ...                             ...
# 2163                0.364519                      105.080574
# 2164                0.393496                       85.947723
# 2165                0.173371                       36.799999
# 2166                0.320570                       89.377243
# 2167                0.503541                      193.118362
#
#       worship_closest_travel_times        GEOID
# 0                       239.923798  36005000100
# 1                        41.152637  36005000200
# 2                        66.196022  36005000400
# 3                        17.588924  36005001600
# 4                       127.937584  36005001900
# ...                            ...          ...
# 2163                     91.388008  36085030302
# 2164                     14.448265  36085031901
# 2165                     82.008224  36085031902
# 2166                    136.685715  36085032300
# 2167                    251.023132  36085990100
#
# [2168 rows x 6 columns]

# %%
zcta_health = pd.read_csv("PLACES__ZCTA_Data__GIS_Friendly_Format___2021_release.csv", dtype={'ZCTA5':'str', 'GEOID':'str'})
zcta_health
# Out:
#        ZCTA5 TotalPopulation  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# 0      08240           2,371                NaN               NaN
# 1      08904          13,982                NaN               NaN
# 2      08065           7,398                NaN               NaN
# 3      28443          17,512               12.4      (11.2, 13.7)
# 4      03103          36,476               17.7      (16.8, 18.8)
# ...      ...             ...                ...               ...
# 32404  90265          18,116                6.4      ( 5.8,  7.0)
# 32405  92567           9,459               19.8      (18.0, 21.6)
# 32406  98237           4,025               12.3      (10.3, 14.5)
# 32407  87564             332               12.2      (10.2, 14.4)
# 32408  95628          40,196                7.9      ( 7.4,  8.4)
#
#        ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  \
# 0                      NaN                 NaN              NaN
# 1                      NaN                 NaN              NaN
# 2                      NaN                 NaN              NaN
# 3                     28.6        (27.8, 29.3)             16.8
# 4                     23.5        (23.1, 23.9)             18.6
# ...                    ...                 ...              ...
# 32404                 21.6        (21.0, 22.2)             18.4
# 32405                 22.1        (21.6, 22.6)             18.0
# 32406                 30.9        (29.5, 32.1)             14.8
# 32407                 26.4        (25.2, 27.5)             14.2
# 32408                 25.1        (24.7, 25.5)             20.5
#
#       BINGE_Crude95CI  BPHIGH_CrudePrev BPHIGH_Crude95CI  ...  \
# 0                 NaN               NaN              NaN  ...
# 1                 NaN               NaN              NaN  ...
# 2                 NaN               NaN              NaN  ...
# 3        (16.5, 17.2)              33.1     (32.3, 33.8)  ...
# 4        (18.4, 18.9)              29.4     (29.0, 29.8)  ...
# ...               ...               ...              ...  ...
# 32404    (18.2, 18.7)              27.3     (26.6, 27.9)  ...
# 32405    (17.7, 18.4)              30.2     (29.6, 30.7)  ...
# 32406    (14.3, 15.3)              32.3     (30.8, 33.5)  ...
# 32407    (13.6, 14.8)              32.0     (30.7, 33.1)  ...
# 32408    (20.3, 20.7)              28.7     (28.3, 29.2)  ...
#
#        OBESITY_Crude95CI PHLTH_CrudePrev  PHLTH_Crude95CI SLEEP_CrudePrev  \
# 0                    NaN             NaN              NaN            35.8
# 1                    NaN             NaN              NaN            34.2
# 2                    NaN             NaN              NaN            37.8
# 3           (30.2, 32.0)            11.4     (10.8, 12.2)            33.3
# 4           (35.2, 36.2)            15.0     (14.4, 15.5)            39.6
# ...                  ...             ...              ...             ...
# 32404       (22.2, 23.3)             9.4     ( 8.9, 10.1)            30.6
# 32405       (33.7, 34.9)            15.0     (14.3, 15.7)            38.9
# 32406       (30.7, 33.5)            16.0     (14.4, 17.6)            33.8
# 32407       (24.1, 26.3)            13.7     (12.4, 15.0)            29.6
# 32408       (25.2, 26.1)            11.4     (10.9, 11.8)            30.9
#
#        SLEEP_Crude95CI STROKE_CrudePrev  STROKE_Crude95CI TEETHLOST_CrudePrev  \
# 0         (32.4, 38.9)              NaN               NaN                 NaN
# 1         (33.4, 35.1)              NaN               NaN                 7.7
# 2         (36.8, 38.8)              NaN               NaN                12.4
# 3         (32.5, 34.1)              3.2      ( 3.0,  3.4)                11.5
# 4         (39.0, 40.1)              3.0      ( 2.9,  3.1)                17.9
# ...                ...              ...               ...                 ...
# 32404     (29.9, 31.3)              2.6      ( 2.5,  2.8)                 5.2
# 32405     (38.3, 39.5)              3.2      ( 3.0,  3.3)                16.5
# 32406     (32.7, 34.9)              4.0      ( 3.6,  4.5)                15.3
# 32407     (28.5, 30.8)              3.4      ( 3.1,  3.8)                12.6
# 32408     (30.5, 31.4)              3.1      ( 3.0,  3.3)                 8.8
#
#        TEETHLOST_Crude95CI                       Geolocation
# 0                      NaN  POINT (-74.53173709 39.48730537)
# 1             ( 5.4, 10.7)   POINT (-74.4289405 40.49812351)
# 2             (10.0, 15.1)    POINT (-75.035071 40.00536195)
# 3             ( 9.3, 14.1)  POINT (-77.67400103 34.40735763)
# 4             (15.4, 20.5)  POINT (-71.44426868 42.95332718)
# ...                    ...                               ...
# 32404         ( 4.0,  6.5)  POINT (-118.8177028 34.05791275)
# 32405         (13.9, 19.2)   POINT (-117.104794 33.81232975)
# 32406         (11.1, 19.8)  POINT (-121.6852387 48.59322161)
# 32407         ( 8.9, 17.2)  POINT (-105.6278913 36.60796943)
# 32408         ( 7.5, 10.2)    POINT (-121.2543305 38.651948)
#
# [32409 rows x 63 columns]

# %%
zip_to_tract = pd.read_csv("zcta_to_tract10.csv", dtype=str)
zip_to_tract = zip_to_tract[['GEOID', 'ZCTA5']]

# %%
tracts_zcta_deserts = pd.merge(tracts_deserts, zip_to_tract, on='GEOID')

# %%
tracts_zcta_deserts
# Out:
#       food_closest_travel_times  physical_closest_dist  \
# 0                    241.000061               0.000338
# 1                    279.976196               0.282170
# 2                    293.006378               0.273411
# 3                    155.181366               0.247503
# 4                    124.599907               0.048832
# ...                         ...                    ...
# 2860                  40.582970               0.353592
# 2861                  40.582970               0.353592
# 2862                  83.954140               0.232066
# 2863                 137.402847               0.318557
# 2864                 189.980087               0.411144
#
#       transport_closest_dist  education_closest_travel_times  \
# 0                   0.000338                      228.306671
# 1                   0.307877                       60.904408
# 2                   0.194327                       66.519920
# 3                   0.087596                       20.076658
# 4                   0.286151                      108.333473
# ...                      ...                             ...
# 2860                0.364519                      105.080574
# 2861                0.364519                      105.080574
# 2862                0.393496                       85.947723
# 2863                0.173371                       36.799999
# 2864                0.320570                       89.377243
#
#       worship_closest_travel_times        GEOID  ZCTA5
# 0                       239.923798  36005000100  11370
# 1                        41.152637  36005000200  10473
# 2                        66.196022  36005000400  10473
# 3                        17.588924  36005001600  10473
# 4                       127.937584  36005001900  10454
# ...                            ...          ...    ...
# 2860                     91.388008  36085030302  10303
# 2861                     91.388008  36085030302  10314
# 2862                     14.448265  36085031901  10303
# 2863                     82.008224  36085031902  10303
# 2864                    136.685715  36085032300  10303
#
# [2865 rows x 7 columns]

# %%
tracts_zcta_deserts = tracts_zcta_deserts.groupby('ZCTA5', as_index=False).median()
tracts_zcta_deserts
# Out:
#      ZCTA5  food_closest_travel_times  physical_closest_dist  \
# 0    10001                  34.733772               0.167533
# 1    10002                  42.952351               0.076797
# 2    10003                  54.583931               0.154937
# 3    10004                  84.726910               0.081697
# 4    10005                  86.738968               0.144094
# ..     ...                        ...                    ...
# 209  11691                 146.671173               0.207410
# 210  11692                  70.289391               0.156135
# 211  11693                  76.302540               0.120755
# 212  11694                 109.728714               0.268667
# 213  11697                 261.851196               0.113599
#
#      transport_closest_dist  education_closest_travel_times  \
# 0                  0.077006                       59.555080
# 1                  0.135394                       25.395082
# 2                  0.081738                       20.200001
# 3                  0.082260                       31.929441
# 4                  0.082453                       28.493832
# ..                      ...                             ...
# 209                0.269644                       57.347967
# 210                0.155561                       41.700539
# 211                0.117169                       53.875572
# 212                0.076101                       71.228714
# 213                0.553558                      288.503510
#
#      worship_closest_travel_times
# 0                       45.433716
# 1                       26.600000
# 2                       35.354568
# 3                       46.507748
# 4                       86.738968
# ..                            ...
# 209                     69.513790
# 210                     63.795357
# 211                     25.768712
# 212                     47.170155
# 213                     63.454735
#
# [214 rows x 6 columns]

# %%
zcta_health = pd.merge(zcta_health, tracts_zcta_deserts, on='ZCTA5')
#zcta_health.to_csv('zcta5_health_nyc.csv', index=False)

# %%
name_mapping = {'access2': 'Health insurance access', 'arthritis': 'Arthritis prevalence', 'binge': 'Binge drinking prevalence',
               'bphigh': 'High blood pressure prevalence', 'bpmed': 'Medium blood pressure prevalence', 'cancer': 'Cancer prevalence',
               'casthma': 'Asthma prevalence', 'cervical': 'Cervical cancer screenings', 'chd': 'Coronary heart disease prevalence',
               'checkup': 'Routine checkups', 'cholscreen': 'Cholesterol screenings', 'colon_screen': 'Colon cancer screenings',
               'copd': 'COPD prevalence', 'corem': 'Core men\'s health', 'corew': 'Core women\'s health', 'csmoking': 'Smoking prevalence',
               'dental': 'Dental checkups', 'depression': 'Depression prevalence', 'diabetes': 'Diabetes prevalence', 'ghlth': 'General poor health prevalence',
               'highchol': 'High cholesterol prevalence', 'kidney': 'Chronic kidney disease', 'lpa': 'No physical activity', 'mammouse': 'Mammograms',
               'mhlth': 'Poor mental health prevalence', 'obesity': 'Obesity prevalence', 'phlth': 'Poor physical health', 'sleep': 'Poor sleep prevalence',
               'stroke': 'Stroke prevalence', 'teethlost': 'Teeth loss prevalence'}

results_nan = pd.DataFrame({'Health condition': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'Food': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')],
                       'Physical health': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'Public transport': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')],
                        'Education': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'Houses of worship': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')],
                       'RSquared': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')], 'MSE': [np.nan for c in zcta_health.columns if c.endswith('CrudePrev')]})

desert_measures = ['food_closest_travel_times', 'physical_closest_dist', 'transport_closest_dist', 'education_closest_travel_times', 'worship_closest_travel_times']

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in zcta_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = np.log(zcta_health[desert_measures].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = zcta_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        data_centered = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        enet_cv = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], 
                                     cv = 10, normalize=True).fit(X_train,y_train)
        
        alpha = enet_cv.alpha_
        l1 = enet_cv.l1_ratio_
        alphas.append(alpha)
        l1_ratios.append(l1)
        
        regr = ElasticNet(alpha=alpha, l1_ratio = l1, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[1]
        results.iat[i, 2] = regr.coef_[3]
        results.iat[i, 3] = regr.coef_[4]
        results.iat[i, 4] = regr.coef_[0]
        results.iat[i, 5] = regr.coef_[2]
        results.iat[i, 6] = regr.score(X_test, y_test)
        results.iat[i, 7] = mse_test
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0           Binge drinking prevalence -0.8366          -0.5179
# 1      High blood pressure prevalence  0.5905           0.4049
# 2               Depression prevalence -0.7810          -0.2437
# 3                          Mammograms -0.6524          -0.1711
# 4    Medium blood pressure prevalence  0.7330           0.7103
# 5                 Diabetes prevalence  0.3343           0.2368
# 6                Arthritis prevalence  0.0000           0.0949
# 7                    Routine checkups  0.2468           0.1819
# 8                     COPD prevalence  0.0000           0.0501
# 9                   Cancer prevalence -0.0000           0.0000
# 10        High cholesterol prevalence  0.1923           0.3428
# 11  Coronary heart disease prevalence -0.0265           0.1260
# 12                  Stroke prevalence  0.0044           0.0442
# 13               No physical activity  0.7448           0.4550
# 14                 Obesity prevalence  0.4277          -0.0000
# 15               Poor physical health  0.0000           0.0000
# 16                  Asthma prevalence -0.1434          -0.0616
# 17     General poor health prevalence  0.0000           0.0000
# 18             Chronic kidney disease -0.0000           0.0028
# 19              Teeth loss prevalence -0.0000           0.0000
# 20                 Smoking prevalence  0.0000           0.0000
# 21                    Dental checkups -0.5583          -0.3914
# 22              Poor sleep prevalence  0.5216          -0.0000
# 23                  Core men's health -0.2664          -0.2011
# 24            Health insurance access  0.1814           0.1497
# 25            Colon cancer screenings -0.6121          -0.2009
# 26      Poor mental health prevalence -0.0000          -0.0000
# 27         Cervical cancer screenings -0.0000          -0.0000
# 28             Cholesterol screenings  0.0000           0.0000
# 29                Core women's health -0.1950          -0.0739
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0             0.4540    -0.5972      -7.987574e-01    0.4649   8.499719
# 1            -1.4492     1.6101       8.421882e-01    0.3086  27.245988
# 2             0.3243    -0.0854      -2.988662e-01    0.2740   3.549193
# 3            -0.2151     0.2070      -8.200620e-01    0.2646   5.627455
# 4            -0.7850     0.4568       1.223346e+00    0.2611  24.452145
# 5            -0.6705     0.6969       1.958623e-01    0.2134   7.893696
# 6            -0.1293     0.5712       8.478739e-01    0.2066  18.031270
# 7            -0.1362     0.3616       3.554208e-01    0.1992  10.234266
# 8            -0.1041     0.3351       2.610245e-01    0.1914   2.090556
# 9             0.0000     0.0000       4.089647e-01    0.1625   4.674431
# 10           -0.1805     0.1435       6.602672e-01    0.1569  17.105295
# 11           -0.1491     0.2123       2.397750e-01    0.1464   2.856623
# 12           -0.1814     0.2340       4.952681e-02    0.1456   0.923285
# 13           -0.8178     1.3676       4.592385e-01    0.1454  47.215347
# 14           -0.9513     2.1907       2.315442e-01    0.1341  26.075474
# 15           -0.3617     0.7169       0.000000e+00    0.1093   7.722815
# 16           -0.1066     0.3411      -1.054764e-01    0.1050   2.227366
# 17           -0.9980     1.3711      -0.000000e+00    0.0985  40.626432
# 18           -0.1208     0.1608       0.000000e+00    0.0845   0.595447
# 19           -0.6947     0.9633      -0.000000e+00    0.0695  32.752663
# 20           -0.1458     0.8572       0.000000e+00    0.0547  11.366987
# 21            0.8658    -0.8920       8.986652e-02    0.0540  72.032763
# 22           -0.5247     1.0035      -0.000000e+00    0.0490  19.429269
# 23            0.6782    -0.4657       2.265169e-01    0.0369  14.527575
# 24           -0.5746     0.4707      -2.350931e-01    0.0323  46.429858
# 25            0.5807    -0.5623      -1.845213e-01    0.0167  42.243411
# 26           -0.0000     0.1649      -0.000000e+00    0.0008   7.419876
# 27            0.0000     0.0000       0.000000e+00   -0.0057  11.645728
# 28            0.0000     0.0000       1.531953e-18   -0.0071   7.927469
# 29            0.2717    -0.1014       5.554573e-02   -0.0699  11.034953

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in zcta_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = zcta_health[desert_measures].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = zcta_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, predictions)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[1]
        results.iat[i, 2] = regr.coef_[3]
        results.iat[i, 3] = regr.coef_[4]
        results.iat[i, 4] = regr.coef_[0]
        results.iat[i, 5] = regr.coef_[2]
        results.iat[i, 6] = regr.score(X_test, y_test)
        results.iat[i, 7] = mse_test

        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4})
results_round.sort_values(by='RSquared', ascending=False).reset_index(drop=True)
# Out:
#                      Health condition    Food  Physical health  \
# 0           Binge drinking prevalence -0.9571          -0.0000
# 1               Depression prevalence -0.9172          -0.1284
# 2                          Mammograms -0.5323           0.0000
# 3      High blood pressure prevalence  0.8668           0.0000
# 4                   Cancer prevalence  0.0000           0.0591
# 5    Medium blood pressure prevalence  0.3447           0.0000
# 6                Arthritis prevalence  0.0000           0.0000
# 7                    Routine checkups  0.1928           0.0434
# 8                 Diabetes prevalence  0.4532          -0.0000
# 9                     COPD prevalence  0.0148          -0.0709
# 10        High cholesterol prevalence  0.0000           0.0000
# 11               No physical activity  0.9983          -0.4334
# 12  Coronary heart disease prevalence  0.0000           0.0000
# 13                 Obesity prevalence  0.7851          -0.3847
# 14                Core women's health -0.4139           0.0076
# 15             Cholesterol screenings  0.0357           0.2162
# 16              Teeth loss prevalence  0.0000          -0.3260
# 17                    Dental checkups -0.7910           0.3659
# 18                  Asthma prevalence -0.0732          -0.1057
# 19               Poor physical health  0.0000          -0.1303
# 20     General poor health prevalence  0.0000          -0.2372
# 21              Poor sleep prevalence  0.6879          -0.1109
# 22            Health insurance access  0.1374          -0.3247
# 23                 Smoking prevalence  0.1188          -0.2805
# 24             Chronic kidney disease  0.0000          -0.0000
# 25      Poor mental health prevalence -0.0000          -0.2641
# 26                  Stroke prevalence  0.0000           0.0000
# 27            Colon cancer screenings -0.8769           0.3494
# 28         Cervical cancer screenings -0.0000           0.0000
# 29                  Core men's health -0.0000           0.0000
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0             0.6422    -0.5454          -1.047291    0.4325   9.065241
# 1             0.3427    -0.0000          -0.287828    0.3293   3.198292
# 2            -0.0000    -0.0000          -0.860800    0.2577   6.126623
# 3            -0.9310     0.9827           0.825605    0.2287  28.230161
# 4             0.0520     0.0148           0.361179    0.1909   3.852047
# 5            -0.0000     0.0000           0.763432    0.1639  24.472968
# 6             0.0000     0.3361           0.673475    0.1636  16.323167
# 7             0.0000     0.2441           0.301009    0.1617   9.296448
# 8            -0.7300     0.4691           0.261888    0.1589   8.520635
# 9            -0.1585     0.2551           0.362204    0.1487   2.072656
# 10            0.0000     0.0000           0.587850    0.1134  16.136305
# 11           -1.4806     1.3207           0.821936    0.1030  52.890531
# 12           -0.0000     0.0769           0.151839    0.0998   2.648269
# 13           -0.7117     1.6610           0.445454    0.0689  29.808265
# 14            0.7698    -0.0000           0.000000    0.0527  10.543216
# 15            0.1754     0.0000           0.180301    0.0457   6.900313
# 16           -0.8426     0.6798           0.000000    0.0433  33.462855
# 17            1.9199    -0.8803          -0.000000    0.0397  76.086619
# 18           -0.0267     0.2146          -0.050060    0.0380   2.246654
# 19           -0.4857     0.4623           0.182629    0.0371   8.510205
# 20           -1.1806     0.8666           0.000000    0.0343  44.653644
# 21           -0.3554     0.6445           0.000000    0.0232  18.866878
# 22           -1.4590     0.3519          -0.000000    0.0181  48.450807
# 23           -0.2570     0.6068           0.230732    0.0061  11.814589
# 24           -0.0670     0.0602           0.000000    0.0012   0.609932
# 25           -0.2210     0.3299           0.000000   -0.0019   7.148088
# 26           -0.0000     0.0000           0.000000   -0.0023   1.000325
# 27            1.0223    -0.4573          -0.328302   -0.0070  44.330961
# 28            0.3115     0.0000           0.000000   -0.0158  11.123639
# 29            0.4128    -0.0000           0.000000   -0.0403  16.397927

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in zcta_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = np.log(zcta_health[desert_measures].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = zcta_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        y_test_pred = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_test = mean_squared_error(y_test, y_test_pred)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[1]
        results.iat[i, 2] = regr.coef_[3]
        results.iat[i, 3] = regr.coef_[4]
        results.iat[i, 4] = regr.coef_[0]
        results.iat[i, 5] = regr.coef_[2]
        results.iat[i, 6] = regr.score(X_test, y_test)
        results.iat[i, 7] = mse_test
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4}).sort_values(by='RSquared', ascending=False).reset_index(drop=True)
results_round
# Out:
#                      Health condition    Food  Physical health  \
# 0           Binge drinking prevalence -0.8094          -0.5561
# 1               Depression prevalence -0.8583          -0.2393
# 2      High blood pressure prevalence  0.5247           0.4884
# 3    Medium blood pressure prevalence  0.6471           0.7903
# 4                          Mammograms -0.5113          -0.0000
# 5                 Diabetes prevalence  0.2942           0.2508
# 6                    Routine checkups  0.2285           0.1927
# 7                Arthritis prevalence  0.0000           0.0566
# 8                     COPD prevalence  0.0000           0.0587
# 9                  Obesity prevalence  0.4684           0.0000
# 10                  Cancer prevalence -0.0000           0.0000
# 11  Coronary heart disease prevalence -0.0310           0.1166
# 12        High cholesterol prevalence  0.0000           0.1736
# 13                  Stroke prevalence  0.0000           0.0455
# 14                  Asthma prevalence -0.1183          -0.0210
# 15               Poor physical health  0.0000           0.0000
# 16     General poor health prevalence  0.0000           0.0000
# 17               No physical activity  0.3974           0.0000
# 18             Chronic kidney disease -0.0000           0.0042
# 19              Poor sleep prevalence  0.5618           0.0000
# 20                    Dental checkups -0.3164          -0.1583
# 21                  Core men's health -0.1406          -0.1901
# 22            Health insurance access  0.0491           0.0247
# 23              Teeth loss prevalence  0.0000           0.0000
# 24                 Smoking prevalence  0.0000           0.0000
# 25            Colon cancer screenings -0.7713          -0.0203
# 26      Poor mental health prevalence -0.0000           0.0000
# 27         Cervical cancer screenings -0.0000          -0.0000
# 28             Cholesterol screenings  0.0000           0.0000
# 29                Core women's health -0.0000          -0.0000
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0             0.5904    -0.6092      -9.445561e-01    0.4844   8.236136
# 1             0.2634    -0.0000      -2.516130e-01    0.3121   3.280416
# 2            -1.5990     1.5823       8.720285e-01    0.3066  25.379300
# 3            -1.0273     0.3573       1.483557e+00    0.2780  21.133689
# 4            -0.1016     0.0000      -8.546182e-01    0.2587   6.118442
# 5            -0.7404     0.8105       1.284392e-01    0.2294   7.806936
# 6            -0.4039     0.5140       5.244275e-01    0.2181   8.670832
# 7            -0.0762     0.5101       7.711769e-01    0.1968  15.675332
# 8            -0.0764     0.3041       2.417723e-01    0.1962   1.957007
# 9            -0.8376     2.1796       1.526586e-01    0.1751  26.408908
# 10            0.0000     0.0000       3.862902e-01    0.1625   3.986968
# 11           -0.1700     0.2307       2.479361e-01    0.1621   2.464879
# 12           -0.0000     0.0000       6.444141e-01    0.1308  15.819594
# 13           -0.1281     0.1993       3.671077e-03    0.1231   0.875161
# 14           -0.0863     0.3183      -9.542871e-02    0.1200   2.055174
# 15           -0.2382     0.5901       0.000000e+00    0.1056   7.904538
# 16           -0.8147     1.2085      -0.000000e+00    0.1009  41.575606
# 17           -0.0000     1.3369       0.000000e+00    0.0984  53.159062
# 18           -0.1002     0.1337       0.000000e+00    0.0961   0.552019
# 19           -0.5612     1.0556      -0.000000e+00    0.0753  17.860523
# 20            0.8783    -1.0742       0.000000e+00    0.0665  73.961351
# 21            0.8289    -0.5725       1.346535e-01    0.0655  14.730393
# 22           -0.8086     0.8176      -2.634471e-01    0.0647  46.149038
# 23           -0.4274     0.7980      -0.000000e+00    0.0630  32.772576
# 24           -0.0000     0.5733       0.000000e+00    0.0425  11.381875
# 25            0.4266    -0.7125      -0.000000e+00    0.0356  42.459287
# 26           -0.0000     0.1015      -0.000000e+00    0.0068   7.086080
# 27            0.0000     0.0000       0.000000e+00   -0.0070  11.027128
# 28            0.0000     0.0000       2.961441e-16   -0.0095   7.299731
# 29            0.0000    -0.0000       0.000000e+00   -0.1221  12.489711

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in zcta_health.columns:
    if c.endswith('CrudePrev'):
        name = name_mapping[c[:-10].lower()]
        
        x = np.log(zcta_health[desert_measures].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = zcta_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(xscale, y.reshape(-1, 1))
        
        y_pred = regr.predict(xscale)
        mse = mean_squared_error(y, y_pred)
        
        results.iat[i, 0] = name
        results.iat[i, 1] = regr.coef_[1]
        results.iat[i, 2] = regr.coef_[3]
        results.iat[i, 3] = regr.coef_[4]
        results.iat[i, 4] = regr.coef_[0]
        results.iat[i, 5] = regr.coef_[2]
        results.iat[i, 6] = regr.score(xscale, y)
        results.iat[i, 7] = mse
            
        i += 1

results_round = results.round({'Food': 4, 'Physical health':4, 'Public transport':4, 'Education':4,
             'House of worship':4, 'RSquared':4}).sort_values(by='RSquared', ascending=False).reset_index(drop=True)
results_round.to_csv('nyc_lasso.csv')
results_round
# Out:
#                      Health condition    Food  Physical health  \
# 0           Binge drinking prevalence -1.1349          -0.3899
# 1               Depression prevalence -0.8528          -0.0796
# 2      High blood pressure prevalence  0.9806           0.2135
# 3                          Mammograms -0.5191          -0.0000
# 4    Medium blood pressure prevalence  0.9072           0.4962
# 5                Arthritis prevalence  0.0503           0.0000
# 6                    Routine checkups  0.4839           0.0959
# 7                  Obesity prevalence  0.2289           0.0000
# 8                   Cancer prevalence  0.0000           0.0000
# 9   Coronary heart disease prevalence  0.0685           0.0418
# 10                Diabetes prevalence  0.4083           0.1228
# 11                    COPD prevalence  0.0668           0.0047
# 12        High cholesterol prevalence  0.0781           0.0024
# 13              Poor sleep prevalence  0.2967           0.0000
# 14                  Stroke prevalence  0.0635           0.0000
# 15                  Asthma prevalence -0.0905          -0.0000
# 16             Chronic kidney disease  0.0000           0.0000
# 17               Poor physical health  0.0000           0.0000
# 18                  Core men's health -0.2176          -0.1411
# 19     General poor health prevalence  0.0000           0.0000
# 20               No physical activity  0.3255           0.0000
# 21                    Dental checkups -0.3556          -0.0560
# 22              Teeth loss prevalence  0.0000           0.0000
# 23            Health insurance access  0.0000           0.0272
# 24            Colon cancer screenings -0.6084          -0.0578
# 25                 Smoking prevalence  0.0000           0.0000
# 26             Cholesterol screenings  0.0000           0.0000
# 27      Poor mental health prevalence -0.0000           0.0000
# 28                Core women's health -0.0000          -0.0000
# 29         Cervical cancer screenings -0.0000          -0.0000
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0             0.5885    -0.6997          -1.051212    0.3615  11.078724
# 1             0.3072    -0.0000          -0.449851    0.3243   3.246455
# 2            -1.6886     1.9181           1.045811    0.2672  25.464614
# 3            -0.0293     0.0000          -0.894435    0.2641   5.751815
# 4            -0.9712     0.4308           1.736297    0.2254  26.720726
# 5            -0.0000     0.5837           1.008939    0.2159  11.020792
# 6            -0.3062     0.5605           0.693887    0.2099   6.775848
# 7            -1.2453     2.4160           0.000000    0.2073  28.526744
# 8             0.0291     0.0000           0.579350    0.1941   2.273303
# 9            -0.1295     0.2652           0.364134    0.1887   1.646994
# 10           -0.9074     0.9588           0.231413    0.1834   9.074466
# 11           -0.0583     0.3686           0.237854    0.1787   1.935830
# 12           -0.0000     0.0000           0.972654    0.1403  12.648331
# 13           -0.8497     1.1322          -0.003068    0.1367  16.209822
# 14           -0.1085     0.2282           0.032396    0.1334   0.815866
# 15           -0.1123     0.4096          -0.224156    0.1060   2.018074
# 16           -0.0785     0.1716           0.000000    0.1025   0.510522
# 17           -0.2614     0.6718           0.000000    0.0950   8.394161
# 18            0.9886    -0.6665           0.160718    0.0950  18.318634
# 19           -1.0005     1.4260          -0.000000    0.0907  43.675256
# 20           -0.0000     1.3100           0.000000    0.0891  59.395240
# 21            1.1198    -1.2905           0.000000    0.0689  81.251157
# 22           -0.6775     0.9206          -0.000000    0.0666  34.930679
# 23           -1.1425     1.0892          -0.326740    0.0644  45.024714
# 24            0.6656    -0.7931           0.000000    0.0622  42.776097
# 25           -0.0000     0.4618          -0.000000    0.0544  11.612561
# 26            0.0000     0.0000           0.101044    0.0180   6.099713
# 27           -0.0000     0.0478          -0.000000    0.0066   6.149412
# 28            0.0185    -0.0000           0.000000    0.0017  14.659099
# 29            0.0000     0.0000           0.000000    0.0000  13.475821
