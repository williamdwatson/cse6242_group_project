# %%
import h5py
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.linear_model import ElasticNet, LinearRegression, Ridge, ElasticNetCV, LassoCV, Lasso
from sklearn.model_selection import GridSearchCV, KFold, train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler, RobustScaler, scale
from distfit import distfit
from sklearn.decomposition import PCA
from scipy.stats import boxcox 
import seaborn as sns 
from haversine import haversine

# %%
zcta_health = pd.read_csv("PLACES__Local_Data_for_Better_Health__ZCTA_Data_2021_release.csv", dtype={'LocationName':'str'})
zcta_health
# Out:
#         Year LocationName DataSource               Category  \
# 0       2019        01775      BRFSS        Health Outcomes
# 1       2019        02163      BRFSS        Health Outcomes
# 2       2019        02568      BRFSS        Health Outcomes
# 3       2019        04071      BRFSS        Health Outcomes
# 4       2019        05640      BRFSS        Health Outcomes
# ...      ...          ...        ...                    ...
# 954320  2019        99208      BRFSS          Health Status
# 954321  2019        99762      BRFSS        Health Outcomes
# 954322  2019        99759      BRFSS        Health Outcomes
# 954323  2019        99546      BRFSS          Health Status
# 954324  2019        99688      BRFSS  Health Risk Behaviors
#
#                                                   Measure Data_Value_Unit  \
# 0                     Stroke among adults aged >=18 years               %
# 1                     Stroke among adults aged >=18 years               %
# 2                     Stroke among adults aged >=18 years               %
# 3                     Stroke among adults aged >=18 years               %
# 4                     Stroke among adults aged >=18 years               %
# ...                                                   ...             ...
# 954320  Fair or poor self-rated health status among ad...               %
# 954321             Arthritis among adults aged >=18 years               %
# 954322  Chronic obstructive pulmonary disease among ad...               %
# 954323  Fair or poor self-rated health status among ad...               %
# 954324       Current smoking among adults aged >=18 years               %
#
#          Data_Value_Type  Data_Value  Data_Value_Footnote_Symbol  \
# 0       Crude prevalence         2.2                         NaN
# 1       Crude prevalence         0.6                         NaN
# 2       Crude prevalence         3.2                         NaN
# 3       Crude prevalence         2.7                         NaN
# 4       Crude prevalence         3.6                         NaN
# ...                  ...         ...                         ...
# 954320  Crude prevalence        17.2                         NaN
# 954321  Crude prevalence        21.0                         NaN
# 954322  Crude prevalence         7.1                         NaN
# 954323  Crude prevalence        21.1                         NaN
# 954324  Crude prevalence        21.6                         NaN
#
#         Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                       NaN                   2.0                    2.6
# 1                       NaN                   0.5                    0.7
# 2                       NaN                   2.8                    3.7
# 3                       NaN                   2.3                    3.0
# 4                       NaN                   3.0                    4.3
# ...                     ...                   ...                    ...
# 954320                  NaN                  16.4                   17.9
# 954321                  NaN                  20.1                   21.7
# 954322                  NaN                   6.2                    8.1
# 954323                  NaN                  19.1                   23.4
# 954324                  NaN                  19.1                   24.0
#
#        TotalPopulation                       Geolocation  LocationID  \
# 0                6,590  POINT (-71.51145308 42.42983302)        1775
# 1                2,582  POINT (-71.12091089 42.36632855)        2163
# 2                4,000     POINT (-70.638878 41.4524563)        2568
# 3                4,801  POINT (-70.44768205 43.93214994)        4071
# 4                  161  POINT (-72.49322605 44.34525233)        5640
# ...                ...                               ...         ...
# 954320          49,193  POINT (-117.4536785 47.73870779)       99208
# 954321           4,038     POINT (-165.364592 64.657639)       99762
# 954322             189  POINT (-162.8271995 69.73094168)       99759
# 954323             326  POINT (-176.6311696 51.84245743)       99546
# 954324           2,759   POINT (-150.460929 61.85685412)       99688
#
#        CategoryID  MeasureId DataValueTypeID Short_Question_Text
# 0         HLTHOUT     STROKE          CrdPrv              Stroke
# 1         HLTHOUT     STROKE          CrdPrv              Stroke
# 2         HLTHOUT     STROKE          CrdPrv              Stroke
# 3         HLTHOUT     STROKE          CrdPrv              Stroke
# 4         HLTHOUT     STROKE          CrdPrv              Stroke
# ...           ...        ...             ...                 ...
# 954320   HLTHSTAT      GHLTH          CrdPrv      General Health
# 954321    HLTHOUT  ARTHRITIS          CrdPrv           Arthritis
# 954322    HLTHOUT       COPD          CrdPrv                COPD
# 954323   HLTHSTAT      GHLTH          CrdPrv      General Health
# 954324    RISKBEH   CSMOKING          CrdPrv     Current Smoking
#
# [954325 rows x 19 columns]

# %%
zcta_health = zcta_health.astype({'Year':'str', 'LocationName':'str'}).set_index('Year').filter(like="2019", axis=0)

# %%
zcta_health = zcta_health.pivot(columns='MeasureId', values='Data_Value', index=['LocationName']).reset_index()
zcta_health.rename(columns={'LocationName':'ZCTA5'}, inplace=True)

# %%
zip_to_tract = pd.read_csv("zcta_tract_rel_10.csv", dtype=str)
zip_to_tract.rename(columns={'GEOID':'TractFIPS'}, inplace=True)
zip_to_tract = zip_to_tract[['TractFIPS', 'ZCTA5']]

# %%
health_cols_raw = ['access2', 'arthritis', 'binge', 'bphigh', 'bpmed', 'cancer', 'casthma', 'cervical', 'chd', 'checkup', 'cholscreen', 'colon_screen', 'copd', 'corem', 'corew', 'csmoking', 'dental', 'depression', 'diabetes', 'ghlth', 'highchol', 'kidney', 'lpa', 'mammouse', 'mhlth', 'obesity', 'phlth', 'sleep', 'stroke', 'teethlost']
health_cols = [x.upper() +'_CrudePrev' for x in health_cols_raw]
desert_measures = ['closest_education_nodes_travel_time','closest_food_nodes_travel_time',
                   'closest_worship_nodes_travel_time', 'physical_dist', 'transport_dist']

# %%
d = {}
l = []
cols = []
with h5py.File('nearest_EM.hdf5', 'r') as h5:
    for k in h5.keys():
        d[k] = h5[k][:]
        l.append(h5[k][:])
        cols.append(k)

# %%
desert_df = pd.DataFrame(np.asarray(l).T, columns = cols)
desert_df = desert_df.astype({'TractFIPS':'int'}).astype({'TractFIPS':'str'})
desert_df = pd.merge(desert_df, zip_to_tract, on='TractFIPS')

# %%
with h5py.File(r'nearest_EM.hdf5', 'r') as f:
    nodes = f['nodes'][:]
    nodes_x = f['nodes_x'][:]
    nodes_y = f['nodes_y'][:]
    physical_proximity_x = f['closest_physical_nodes_x'][:]
    physical_proximity_y = f['closest_physical_nodes_y'][:]
    transport_proximity_x = f['closest_transport_nodes_x'][:]
    transport_proximity_y = f['closest_transport_nodes_y'][:]
smaller_bounds = (nodes_x > -74.4) & (nodes_x < -73.6) & (nodes_y < 41)
nodes = nodes[smaller_bounds]
nodes_x = nodes_x[smaller_bounds]
nodes_y = nodes_y[smaller_bounds]
physical_proximity_x = physical_proximity_x[smaller_bounds]
physical_proximity_y = physical_proximity_y[smaller_bounds]
transport_proximity_x = transport_proximity_x[smaller_bounds]
transport_proximity_y = transport_proximity_y[smaller_bounds]

# %%
def haversine_wrapper(lat1, lon1, lat2, lon2):
    return haversine((lat1, lon1), (lat2, lon2))
physical_dist = np.zeros_like(nodes_x)
transport_dist = np.zeros_like(nodes_x)
for i in tqdm(range(len(nodes_x))):
    physical_dist[i] = haversine_wrapper(nodes_y[i], nodes_x[i], physical_proximity_y[i], physical_proximity_x[i])
    transport_dist[i] = haversine_wrapper(nodes_y[i], nodes_x[i], transport_proximity_y[i], transport_proximity_x[i])
desert_df['physical_dist'] = np.nan
desert_df['transport_dist'] = np.nan
num_missed = 0
for i in tqdm(desert_df.index, total=desert_df.shape[0]):
    try:
        idx = np.where(nodes == desert_df.at[i, 'nodes'])[0][0]
        desert_df.at[i, 'physical_dist'] = physical_dist[idx]
        desert_df.at[i, 'transport_dist'] = transport_dist[idx]
    except IndexError:
        num_missed += 1
print('Missed:', num_missed)
# Out:
# 100%|████████████████████████████████████| 2117/2117 [00:00<00:00, 85945.19it/s]
# 100%|████████████████████████████████████| 2810/2810 [00:00<00:00, 38381.73it/s]
# Missed: 0

# %%
desert_df = desert_df[desert_measures+['ZCTA5']]
# Out:
#       closest_education_nodes_travel_time  closest_food_nodes_travel_time  \
# 0                                     4.0                             3.0
# 1                                     7.0                             3.0
# 2                                     7.0                             3.0
# 3                                     9.0                             7.0
# 4                                     4.0                            11.0
# ...                                   ...                             ...
# 2805                                  0.0                             2.0
# 2806                                  3.0                             4.0
# 2807                                  5.0                             9.0
# 2808                                  2.0                             1.0
# 2809                                  2.0                             1.0
#
#       closest_worship_nodes_travel_time  physical_dist  transport_dist  ZCTA5
# 0                                   4.0       0.158174        0.498002  11220
# 1                                   7.0       0.377913        0.535944  11219
# 2                                   7.0       0.377913        0.535944  11220
# 3                                   9.0       0.797871        0.617204  11230
# 4                                   4.0       0.679142        0.333808  10469
# ...                                 ...            ...             ...    ...
# 2805                                0.0       0.286232        0.000000  11229
# 2806                                3.0       0.556792        0.324271  10019
# 2807                                5.0       0.307807        0.339795  11433
# 2808                                2.0       0.461220        0.160318  10017
# 2809                                2.0       0.461220        0.160318  10022
#
# [2810 rows x 6 columns]

# %%
desert_df = desert_df.groupby('ZCTA5', as_index=False).median()
# Out:
#      ZCTA5  closest_education_nodes_travel_time  \
# 0    10001                                  2.0
# 1    10002                                  3.0
# 2    10003                                  3.0
# 3    10004                                  4.0
# 4    10005                                  2.0
# ..     ...                                  ...
# 206  11691                                  3.0
# 207  11692                                  2.0
# 208  11693                                  2.0
# 209  11694                                  1.0
# 210  11697                                 34.0
#
#      closest_food_nodes_travel_time  closest_worship_nodes_travel_time  \
# 0                               1.0                                2.0
# 1                               2.0                                3.0
# 2                               3.0                                3.0
# 3                               4.0                                4.0
# 4                               4.0                                2.0
# ..                              ...                                ...
# 206                             9.0                                3.0
# 207                             6.0                                2.0
# 208                             8.5                                2.0
# 209                            13.0                                1.0
# 210                             6.0                               34.0
#
#      physical_dist  transport_dist
# 0         0.416515        0.156657
# 1         0.129459        0.155874
# 2         0.439944        0.142336
# 3         0.394331        0.148273
# 4         0.641055        0.148273
# ..             ...             ...
# 206       0.328309        0.287184
# 207       0.223313        0.155681
# 208       0.305888        0.117108
# 209       0.486986        0.076193
# 210       0.086519        3.100998
#
# [211 rows x 6 columns]

# %%
nyc_health = pd.merge(zcta_health, desert_df, on='ZCTA5')

# %%
nyc_health.to_csv('nyc_health_zcta5.csv', index=False)

# %%
name_mapping = {'access2': 'Health insurance access', 'arthritis': 'Arthritis prevalence', 'binge': 'Binge drinking prevalence',
               'bphigh': 'High blood pressure prevalence', 'bpmed': 'Medium blood pressure prevalence', 'cancer': 'Cancer prevalence',
               'casthma': 'Asthma prevalence', 'cervical': 'Cervical cancer screenings', 'chd': 'Coronary heart disease prevalence',
               'checkup': 'Routine checkups', 'cholscreen': 'Cholesterol screenings', 'colon_screen': 'Colon cancer screenings',
               'copd': 'COPD prevalence', 'corem': 'Core men\'s health', 'corew': 'Core women\'s health', 'csmoking': 'Smoking prevalence',
               'dental': 'Dental checkups', 'depression': 'Depression prevalence', 'diabetes': 'Diabetes prevalence', 'ghlth': 'General poor health prevalence',
               'highchol': 'High cholesterol prevalence', 'kidney': 'Chronic kidney disease', 'lpa': 'No physical activity', 'mammouse': 'Mammograms',
               'mhlth': 'Poor mental health prevalence', 'obesity': 'Obesity prevalence', 'phlth': 'Poor physical health', 'sleep': 'Poor sleep prevalence',
               'stroke': 'Stroke prevalence', 'teethlost': 'Teeth loss prevalence'}

results_nan = pd.DataFrame({'Health condition': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())], 'Food': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())],
                       'Physical health': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())], 'Public transport': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())],
                        'Education': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())], 'Houses of worship': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())],
                       'RSquared': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())], 'MSE': [np.nan for c in nyc_health.columns if c.lower() in list(name_mapping.keys())]})

# %%
def update_results(results, model, i, X_test, y_test, name):
    results.iat[i, 0] = name
    results.iat[i, 1] = model.coef_[1]
    results.iat[i, 2] = model.coef_[3]
    results.iat[i, 3] = model.coef_[4]
    results.iat[i, 4] = model.coef_[0]
    results.iat[i, 5] = model.coef_[2]
    results.iat[i, 6] = model.score(X_test, y_test)

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in nyc_health.columns:
    if c.lower() in list(name_mapping.keys()):
        name = name_mapping[c.lower()]
        
        x = nyc_health[desert_measures].to_numpy(copy=True)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = nyc_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        update_results(results, regr, i, X_test, y_test, name)
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_train = mean_squared_error(y_test, predictions)
        results.iat[i,6] = r2_score(y_test, predictions)
        results.iat[i, 7] = mse_train
        #make_resid_plot(predictions, X_test, y_test, name, i)
        
        #residuals = y_test - predictions
        #make_qq_plot(residuals, X_test, y_test, name, i)
        #make_htsk_plot(residuals, predictions, name, i)
            
        i += 1

#layout_resid_plot()
#plt.savefig('plots/all_deserts/elasticnet_resid.png', transparent=False, dpi=300)
results
# Out:
#                      Health condition          Food  Physical health  \
# 0             Health insurance access  5.327505e-01        -0.068336
# 1                Arthritis prevalence  1.011047e+00         0.000000
# 2           Binge drinking prevalence -1.366137e+00        -0.453972
# 3      High blood pressure prevalence  2.158583e+00        -0.112371
# 4    Medium blood pressure prevalence  9.143748e-01         0.000000
# 5                   Cancer prevalence  0.000000e+00         0.000000
# 6                   Asthma prevalence  2.944461e-01        -0.271277
# 7   Coronary heart disease prevalence  4.914690e-01         0.000000
# 8                    Routine checkups  6.482554e-01         0.089402
# 9              Cholesterol screenings  0.000000e+00         0.016804
# 10                    COPD prevalence  5.826835e-01        -0.054030
# 11                 Smoking prevalence  5.224522e-16        -0.000000
# 12              Depression prevalence -1.972821e-01        -0.473396
# 13                Diabetes prevalence  1.007206e+00        -0.145916
# 14     General poor health prevalence  1.873475e+00        -0.797583
# 15        High cholesterol prevalence  6.507464e-01         0.271239
# 16             Chronic kidney disease  2.298418e-01        -0.095687
# 17               No physical activity  2.588897e+00        -0.188800
# 18      Poor mental health prevalence  3.865880e-01        -0.260256
# 19                 Obesity prevalence  1.152941e+00        -0.000000
# 20               Poor physical health  9.505255e-01        -0.330891
# 21                  Stroke prevalence  2.997030e-01        -0.079353
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0          -0.000000  -0.647682      -1.765684e-01  0.000172  53.178015
# 1           0.748693   0.000000       0.000000e+00  0.149223   8.483151
# 2          -2.897606   1.886750       3.065907e-01  0.193308  13.170021
# 3           4.001540  -3.047577      -6.069610e-01  0.090882  29.828959
# 4           1.055139   0.000000       0.000000e+00  0.116623  19.543920
# 5           0.094235   0.000000       0.000000e+00  0.030952   1.547857
# 6          -0.000000  -0.114625      -9.758766e-02  0.086133   1.801856
# 7           1.445533  -1.155756      -1.147518e-01  0.001369   1.413930
# 8           0.480713   0.000000       0.000000e+00  0.109665   8.042561
# 9           0.000000   0.328563       7.256530e-17  0.013649   7.027436
# 10          1.371605  -1.117424      -1.806502e-01  0.054816   2.104213
# 11         -0.000000  -0.000000      -0.000000e+00 -0.018450  12.290970
# 12         -0.217354  -0.020491      -3.457927e-02  0.105407   4.702033
# 13          2.054535  -1.883800      -3.306077e-01  0.047087  10.977021
# 14          3.708166  -4.008050      -6.209220e-01  0.020208  48.816345
# 15          0.824917   0.000000       0.000000e+00  0.029953  10.055032
# 16          0.712716  -0.667104      -7.554803e-02 -0.001113   0.493020
# 17          4.027650  -3.698271      -8.191417e-01  0.050624  67.555479
# 18         -0.000000  -0.223880      -1.281261e-01  0.059063   5.316266
# 19         -0.000000  -0.000000      -0.000000e+00  0.125932  30.816790
# 20          1.969727  -1.913623      -3.150307e-01  0.020736   9.069905
# 21          0.877694  -0.790133      -9.887622e-02  0.026699   0.836166

# %%
alphas = []
l1_ratios = []
i=0
results = results_nan.copy()

plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

for c in nyc_health.columns:
    if c.lower() in list(name_mapping.keys()):
        name = name_mapping[c.lower()]
        
        x = np.log(nyc_health[desert_measures].to_numpy(copy=True)+1)
        scaler = StandardScaler()
        xscale = scaler.fit_transform(x)
        y = nyc_health[c].to_numpy(copy=True)
        xscale = xscale[~np.isnan(y)]
        y = y[~np.isnan(y)]
        #create function to center data
        center_function = lambda x: x - x.mean()

        #apply function to original NumPy array
        y = center_function(y)
        
        X_train, X_test, y_train, y_test = train_test_split(xscale, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=42)
        
        #l1 ratio is from suggested values in ElasticNetCV documentation
        lasso_cv = LassoCV(cv = 5, normalize=True).fit(X_train,y_train)
        
        alpha = lasso_cv.alpha_
        alphas.append(alpha)
        
        regr = Lasso(alpha=alpha, normalize=True)  # Could try others, or other parameters?
        regr.fit(X_train, y_train.reshape(-1, 1))
        
        update_results(results, regr, i, X_test, y_test, name)
        
        predictions = regr.predict(X_test)
        y_train_pred = regr.predict(X_train)
        mse_train = mean_squared_error(y_test, predictions)
        results.iat[i,6] = r2_score(y_test, predictions)
        results.iat[i, 7] = mse_train
        #make_resid_plot(predictions, X_test, y_test, name, i)
        
        #residuals = y_test - predictions
        #make_qq_plot(residuals, X_test, y_test, name, i)
        #make_htsk_plot(residuals, predictions, name, i)
            
        i += 1

#layout_resid_plot()
#plt.savefig('plots/all_deserts/elasticnet_resid.png', transparent=False, dpi=300)
results
# Out:
#                      Health condition      Food  Physical health  \
# 0             Health insurance access  1.648295        -0.246499
# 1                Arthritis prevalence  0.724573         0.000000
# 2           Binge drinking prevalence -1.311289        -0.270992
# 3      High blood pressure prevalence  1.869092         0.000000
# 4    Medium blood pressure prevalence  0.651696         0.000000
# 5                   Cancer prevalence  0.000000         0.000000
# 6                   Asthma prevalence  0.440955        -0.283702
# 7   Coronary heart disease prevalence  0.510260        -0.000000
# 8                    Routine checkups  0.539085         0.002933
# 9              Cholesterol screenings -0.000000         0.000000
# 10                    COPD prevalence  0.700558        -0.070938
# 11                 Smoking prevalence  1.294538        -0.309717
# 12              Depression prevalence -0.295924        -0.479399
# 13                Diabetes prevalence  0.790889        -0.000000
# 14     General poor health prevalence  2.621103        -0.667361
# 15        High cholesterol prevalence  0.254061         0.000000
# 16             Chronic kidney disease  0.311962        -0.105602
# 17               No physical activity  2.053938         0.000000
# 18      Poor mental health prevalence  0.779710        -0.314950
# 19                 Obesity prevalence  1.613130        -0.000000
# 20               Poor physical health  1.406098        -0.397290
# 21                  Stroke prevalence  0.195435        -0.000000
#
#     Public transport  Education  Houses of worship  RSquared        MSE
# 0          -0.000000  -0.558465          -0.803824 -0.001479  53.265823
# 1           0.846183  -0.000000          -0.000000  0.183144   8.144923
# 2          -0.825087   0.000000           0.000000  0.273932  11.853758
# 3           0.271929  -0.000000          -0.000000  0.205913  26.054690
# 4           1.294231   0.000000           0.000000  0.138536  19.059119
# 5           0.493828   0.000000           0.000000  0.112534   1.417547
# 6           0.000000  -0.131988          -0.215040  0.113246   1.748398
# 7           0.927233  -0.645141          -0.179951  0.107946   1.263030
# 8           0.531370   0.000000           0.000000  0.118394   7.963712
# 9           0.212091   0.169104           0.000000 -0.004804   7.158908
# 10          0.891750  -0.631652          -0.302144  0.095126   2.014473
# 11          0.000000  -0.000000          -0.544766  0.115769  10.671173
# 12         -0.000000  -0.456253          -0.003674  0.127699   4.584866
# 13          0.000000  -0.000000          -0.000000  0.129512  10.027534
# 14          0.582728  -0.775208          -1.278232  0.069349  46.367996
# 15          0.733253   0.000000           0.000000  0.044029   9.909123
# 16          0.392747  -0.346085          -0.146607  0.044141   0.470733
# 17          0.000000  -0.000000          -0.000000  0.124891  62.270817
# 18         -0.000000  -0.224896          -0.380241  0.044367   5.399298
# 19         -0.000000  -0.000000          -0.000000  0.203996  28.064500
# 20          1.257640  -1.189291          -0.685711  0.017378   9.101010
# 21          0.000000  -0.000000          -0.000000  0.120639   0.755462
